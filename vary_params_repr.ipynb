# %%
import torch
device = 'cpu'
import matplotlib.pyplot as plt
import numpy as np
from models.training import create_dataloader_param
import scipy.io as io


# Juptyer magic: For export. Makes the plots size right for the screen 
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %config InlineBackend.figure_formats = ['svg'] 

torch.backends.cudnn.deterministic = True
seed = np.random.randint(1,200)
seed = 56
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
print(seed)
g = torch.Generator()
g.manual_seed(seed)

# design choices 
chosen_problem = 'repr_alt'
data_noise = 0.
n_different_weights = 1
if n_different_weights == 1:
    print('This choice will generate autonomous dynamics')
else:
    print('This choice generates non-autonomous dynamics, letting the weights depend on time')

possible_problem = {'moons':'moons', 'ToggleSwitch':'TS', 'repressilator':'repr', 'restricted_TS': 'restrictedTS','repr_alt':'repr_alt'} 
# this choices determine the data set that we build and subsequent choices on the construction of the neural ODE 
# - in particular, it determines the dimensions 
problem = possible_problem[chosen_problem]

plotlim = [0, 5]
# Out:
# 56
# This choice will generate autonomous dynamics

# %%
ind = 0
m1vec = []
m2vec = []
lossvec = []
var1vec = []
var2vec = []

A1 = np.array([[0,1,0],[1,0,0],[0,0,0]])
A2 = np.array([[0,1,0],[0,0,1],[1,0,0]])
c1 = 2
c2 = 2.2

for eps in np.linspace(0,1,21):

    m1vectemp = []
    m2vectemp = []
    lossvectemp = []
    Xtempvec = []
    W1vec = []

    A = eps*A1 + (1-eps)*A2
    c = eps*c1 + (1-eps)*c2

    for k in range(0,50):
        
        ind = ind + 1
        seed = ind
        
        dataloader, dataloader_viz, X_train = create_dataloader_param(problem,A,c, batch_size = 10, noise = data_noise, 
                                                    plotlim = plotlim, random_state = seed, label = 'vector')
        print('eps = ' + str(eps) + ', iteration ' + str(k))
        #print(X_train.detach().numpy())

        #Import of the model dynamics that describe the neural ODE
        #The dynamics are based on the torchdiffeq package, that implements ODE solvers in the pytorch setting
        from models.neural_odes import NeuralODE

        #T is the end time of the neural ODE evolution, num_steps are the amount of discretization steps for the ODE solver
        T, num_steps = 1, n_different_weights
        bound = 0.
        fp = False
        cross_entropy = False
        turnpike = False

        # choice of model: what nonlinearity is used and if the nonlinearity is applied before (inside) or after (outside) the linear weights
        # another choice is bottleneck, but I don't understand it
        # non_linearity = 'tanh' # OR 'relu' 'sigmoid' 'leakyrelu' 'tanh_prime'
        # architecture = 'inside' 'outside'
        non_linearity = 'tanh'
        architecture = 'inside'
        architectures = {'inside': -1, 'outside': 0, 'bottleneck': 1, 'restricted': 2, 'restr_repr':3}
        # number of optimization runs in which the dataset is used for gradient decent
        num_epochs = 50
        if problem == 'moons' or problem == 'TS' or problem == "restrictedTS":
            hidden_dim, data_dim = 2, 2 
        else:
            hidden_dim, data_dim = 3, 3 
        augment_dim = 0

        # resets the seed - allows for coherent runs in the gradient descent as well
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        anode = NeuralODE(device, data_dim, hidden_dim, output_dim=data_dim, augment_dim=augment_dim, non_linearity=non_linearity, 
                            architecture=architecture, T=T, time_steps=num_steps, fixed_projector=fp, cross_entropy=cross_entropy)
        optimizer_anode = torch.optim.Adam(anode.parameters(), lr=1e-1)

        from models.training import doublebackTrainer

        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        trainer_anode = doublebackTrainer(anode, optimizer_anode, device, cross_entropy=cross_entropy, turnpike = turnpike,
                                bound=bound, fixed_projector=fp, verbose = False, eps_comp = 0.2)

        trainer_anode.train(dataloader, 400)

        W1 = anode.flow.dynamics.fc2_time[0].weight
        W1 = W1.detach().numpy()
        m1 = abs(W1[0][1]-W1[1][0])
        m2 = abs(W1[0][0])+abs(W1[1][1])

        lv = trainer_anode.histories["loss_history"]
        l = lv[-1]

        m1vectemp.append(m1)
        m2vectemp.append(m2)
        lossvectemp.append(l)
        Xtempvec.append(X_train.detach().numpy())
        W1vec.append(W1)
    
    mdic = {"X":Xtempvec,"l":lossvectemp,"symm":m1vectemp,"offdiag":m2vectemp,"W1":W1vec}
    io.savemat("param_fit_eps_"+str(eps)+".mat",mdic)
    m1vec.append(np.mean(m1vectemp))
    m2vec.append(np.mean(m2vectemp))
    lossvec.append(np.mean(lossvectemp))
    var1vec.append(np.var(m1vectemp))
    var2vec.append(np.var(m2vectemp))
# Out:
# No change  applied to TS or repr data
# eps = 0.0, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.0, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.05, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.1, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.15000000000000002, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.2, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.25, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.30000000000000004, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.35000000000000003, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.4, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.45, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.5, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.55, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.6000000000000001, iteration 48
# inside
# ...
# eps = 0.8, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.8, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.8500000000000001, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.9, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 0.9500000000000001, iteration 49
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 0
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 1
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 2
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 3
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 4
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 5
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 6
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 7
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 8
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 9
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 10
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 11
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 12
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 13
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 14
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 15
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 16
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 17
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 18
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 19
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 20
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 21
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 22
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 23
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 24
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 25
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 26
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 27
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 28
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 29
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 30
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 31
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 32
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 33
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 34
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 35
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 36
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 37
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 38
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 39
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 40
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 41
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 42
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 43
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 44
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 45
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 46
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 47
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 48
# inside
# No change  applied to TS or repr data
# eps = 1.0, iteration 49
# inside
