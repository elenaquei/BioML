# %%
import torch
import numpy as np
from models.training import easyTrainer, weights_to_dataset
from models.nODE import nODE, make_nODE_from_parameters
import matplotlib.pyplot as plt
from torch_geometric.data import Data
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv
from torch_geometric.loader import DataLoader

# %%
adj_list = []
adj_list.append(np.array([[0.,0.],[0.,0.]]))
adj_list.append(np.array([[0,1.],[0,0]]))
adj_list.append(np.array([[0,-1.],[0,0]]))
adj_list.append(np.array([[0,1.],[1.,0]]))
adj_list.append(np.array([[0,1.],[-1.,0]]))
adj_list.append(np.array([[0,-1.],[-1.,0]]))

# %%
def generate_data(adj,y,ndata=4):
    ODE_dim = 2
    Gamma = np.array([-1., -1.])
    integration_time = 1
    Win = adj
    Wout = np.array([[2., 0], [0, 2.]])
    bin = np.array([[2.], [2.]])
    bout = np.array([[2.], [2.]])

    train_data, test_data = weights_to_dataset(integration_time, Gamma, Win=Win, bin=bin, Wout=Wout, bout=bout, batch_size = ndata)
    print(train_data)
    edge_index = torch.tensor([[0, 1],
                           [1, 0]], dtype=torch.long)
    
    for i, (x1, x_batch) in enumerate(train_data):
        print(x_batch)
        print(x1)
        x = torch.tensor([[x1[0][0]],[x_batch[0][0]],[x1[0][1]],[x_batch[0][1]],[x1[1][0]],[x_batch[1][0]],[x1[1][1]],[x_batch[1][1]]], dtype=torch.float)

        y = torch.tensor([y])

        data = Data(x= x, edge_index=edge_index,y=y)

    return data

data_list = []
for graph_ind in [0,1,2,3,4,5]:
    for i in range(0,100):
        ind = 0
        data = generate_data(adj_list[graph_ind],graph_ind)
        data_list.append(data)
loader = DataLoader(data_list, batch_size=32, shuffle=True)

test_data_list = []
for graph_ind in [0,1,2,3,4,5]:
    for i in range(0,20):
        ind = 0
        data = generate_data(adj_list[graph_ind],graph_ind)
        test_data_list.append(data)
test_loader = DataLoader(data_list, batch_size=32, shuffle=True)

for data in loader:
    print(data)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x000002519E6BEBF0>
# tensor([[3.6489, 2.6345],
#         [4.0457, 2.5668]])
# tensor([[3.1692, 0.4119],
#         [4.2478, 0.2277]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C6DB7880>
# tensor([[3.1214, 3.8596],
#         [4.1472, 3.9641]])
# tensor([[1.7353, 3.7419],
#         [4.5239, 4.0260]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C57E39D0>
# tensor([[4.1075, 3.3877],
#         [2.8591, 4.1372]])
# tensor([[4.4159, 2.4592],
#         [1.0224, 4.4966]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE9E7FA0>
# tensor([[3.5281, 3.2534],
#         [3.5642, 4.1838]])
# tensor([[2.8408, 2.0940],
#         [2.9389, 4.6232]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7036920>
# tensor([[2.7344, 2.8098],
#         [2.5634, 4.2354]])
# tensor([[0.6833, 0.8883],
#         [0.2184, 4.7635]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7034940>
# tensor([[3.9114, 3.1648],
#         [3.7626, 3.3399]])
# tensor([[3.8829, 1.8533],
#         [3.4782, 2.3293]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE9E6EF0>
# tensor([[3.9312, 3.2826],
#         [2.5038, 3.9127]])
# tensor([[3.9366, 2.1734],
#         [0.0566, 3.8863]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7035180>
# tensor([[2.6295, 2.5165],
#         [3.6546, 3.9871]])
# tensor([[0.3982, 0.0910],
#         [3.1846, 4.0885]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7035150>
# tensor([[4.1723, 3.2396],
#         [2.7880, 3.7818]])
# tensor([[4.5921, 2.0566],
#         [0.8291, 3.5304]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7036920>
# tensor([[3.0800, 3.7191],
#         [4.0397, 3.6094]])
# tensor([[1.6228, 3.3601],
#         [4.2316, 3.0618]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B3D0>
# tensor([[3.6020, 3.4711],
#         [3.8771, 3.3061]])
# tensor([[3.0418, 2.6859],
#         [3.7896, 2.2373]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B910>
# tensor([[3.8320, 3.0084],
#         [2.5109, 3.3782]])
# tensor([[3.6669, 1.4282],
#         [0.0758, 2.4335]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B580>
# tensor([[3.7548, 3.2263],
#         [3.3903, 2.7782]])
# tensor([[3.4572, 2.0204],
#         [2.4663, 0.8025]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B610>
# tensor([[4.1900, 2.5470],
#         [3.5692, 3.2385]])
# tensor([[4.6400, 0.1740],
#         [2.9527, 2.0538]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B7F0>
# tensor([[4.2268, 3.0319],
#         [2.6282, 3.0294]])
# tensor([[4.7402, 1.4921],
#         [0.3947, 1.4853]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C5E0B4C0>
# tensor([[3.3809, 3.6947],
#         [3.3614, 4.2871]])
# tensor([[2.4407, 3.2938],
#         [2.3879, 4.9041]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC11900>
# tensor([[3.7299, 2.8192],
#         [2.4970, 3.8454]])
# tensor([[3.3893, 0.9139],
#         [0.0379, 3.7034]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFB398A0>
# tensor([[2.9338, 2.8819],
#         [3.6477, 2.8500]])
# tensor([[1.2253, 1.0843],
#         [3.1659, 0.9975]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210E20>
# tensor([[3.4019, 2.5636],
#         [2.8202, 2.5137]])
# tensor([[2.4978, 0.2192],
#         [0.9167, 0.0835]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211450>
# tensor([[3.4676, 3.4709],
#         [3.6763, 2.9548]])
# tensor([[2.6765, 2.6855],
#         [3.2436, 1.2824]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211450>
# tensor([[3.5306, 2.6978],
#         [2.9979, 3.0661]])
# tensor([[2.8477, 0.5839],
#         [1.3997, 1.5849]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213760>
# tensor([[2.7583, 2.5913],
#         [3.5408, 4.2675]])
# tensor([[0.7484, 0.2945],
#         [2.8755, 4.8506]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211AB0>
# tensor([[4.2724, 3.9006],
#         [3.6138, 2.8313]])
# tensor([[4.8640, 3.8534],
#         [3.0738, 0.9466]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210430>
# tensor([[3.9956, 3.5063],
#         [3.6832, 2.8027]])
# tensor([[4.1117, 2.7815],
#         [3.2626, 0.8690]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211450>
# tensor([[3.7067, 2.6815],
#         [2.5616, 4.0103]])
# tensor([[3.3263, 0.5395],
#         [0.2136, 4.1515]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213760>
# tensor([[4.1482, 4.1723],
#         [2.6750, 2.5906]])
# tensor([[4.5265, 4.5920],
#         [0.5220, 0.2925]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211AB0>
# tensor([[4.2445, 2.5354],
#         [3.0891, 2.9507]])
# tensor([[4.7883, 0.1426],
#         [1.6476, 1.2713]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210430>
# tensor([[4.1436, 3.0940],
#         [3.3810, 2.9332]])
# tensor([[4.5140, 1.6610],
#         [2.4409, 1.2236]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211990>
# tensor([[2.7260, 3.0900],
#         [4.3018, 3.1514]])
# tensor([[0.6606, 1.6501],
#         [4.9440, 1.8169]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211510>
# tensor([[2.8736, 4.0043],
#         [3.1748, 2.5463]])
# tensor([[1.0619, 4.1352],
#         [1.8806, 0.1719]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72133A0>
# tensor([[4.1238, 2.8854],
#         [2.6993, 3.4982]])
# tensor([[4.4603, 1.0939],
#         [0.5878, 2.7595]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7212650>
# tensor([[2.6441, 3.5205],
#         [3.7625, 3.4546]])
# tensor([[0.4378, 2.8203],
#         [3.4780, 2.6410]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72115A0>
# tensor([[3.3473, 3.5650],
#         [3.5306, 4.2413]])
# tensor([[2.3494, 2.9412],
#         [2.8476, 4.7795]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210460>
# tensor([[3.5857, 4.2512],
#         [3.5702, 3.2545]])
# tensor([[2.9974, 4.8065],
#         [2.9553, 2.0972]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210910>
# tensor([[3.7650, 2.4893],
#         [3.5537, 2.8303]])
# tensor([[3.4849, 0.0172],
#         [2.9104, 0.9440]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7212110>
# tensor([[2.5430, 2.8603],
#         [2.6284, 3.5009]])
# tensor([[0.1632, 1.0255],
#         [0.3952, 2.7670]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210AF0>
# tensor([[3.3031, 3.2230],
#         [3.0013, 2.5200]])
# tensor([[2.2294, 2.0114],
#         [1.4089, 0.1006]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72124A0>
# tensor([[3.4445, 4.0582],
#         [3.7178, 3.3290]])
# tensor([[2.6137, 4.2819],
#         [3.3566, 2.2996]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7212CE0>
# tensor([[3.9050, 2.4971],
#         [4.0886, 2.5204]])
# tensor([[3.8653, 0.0382],
#         [4.3644, 0.1017]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7212500>
# tensor([[3.3901, 3.2360],
#         [4.2124, 2.9544]])
# tensor([[2.4657, 2.0469],
#         [4.7009, 1.2814]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213D00>
# tensor([[4.2738, 4.2302],
#         [3.6692, 3.5034]])
# tensor([[4.8680, 4.7492],
#         [3.2243, 2.7736]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211270>
# tensor([[4.0751, 3.1348],
#         [3.5298, 3.3699]])
# tensor([[4.3278, 1.7718],
#         [2.8455, 2.4110]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213520>
# tensor([[2.5638, 4.0814],
#         [3.4024, 3.3760]])
# tensor([[0.2197, 4.3450],
#         [2.4991, 2.4273]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210C10>
# tensor([[3.1698, 3.2678],
#         [4.2863, 2.8586]])
# tensor([[1.8670, 2.1334],
#         [4.9020, 1.0210]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72137C0>
# tensor([[2.8140, 3.5622],
#         [3.0492, 3.8280]])
# tensor([[0.8997, 2.9336],
#         [1.5391, 3.6560]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211E10>
# tensor([[3.1189, 3.4180],
#         [3.8494, 3.1113]])
# tensor([[1.7285, 2.5415],
#         [3.7143, 1.7079]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72135B0>
# tensor([[2.8695, 2.6312],
#         [3.2026, 4.1575]])
# tensor([[1.0507, 0.4028],
#         [1.9561, 4.5517]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210550>
# tensor([[4.0745, 3.7368],
#         [4.0194, 4.0563]])
# tensor([[4.3260, 3.4083],
#         [4.1763, 4.2768]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C6DC17B0>
# tensor([[4.1606, 3.2461],
#         [3.2602, 4.0380]])
# tensor([[4.5603, 2.0744],
#         [2.1125, 4.2270]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B8670>
# tensor([[2.9465, 4.2716],
#         [4.0204, 3.2231]])
# tensor([[1.2598, 4.8620],
#         [4.1791, 2.0118]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B8670>
# tensor([[3.8409, 3.1286],
#         [3.0847, 3.4486]])
# tensor([[3.6912, 1.7549],
#         [1.6356, 2.6249]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B9AB0>
# tensor([[3.3473, 2.9775],
#         [3.7634, 2.9684]])
# tensor([[2.3494, 1.3441],
#         [3.4804, 1.3193]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B8670>
# tensor([[2.5373, 3.4000],
#         [3.6154, 3.4904]])
# tensor([[0.1477, 2.4927],
#         [3.0782, 2.7384]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251B7F645B0>
# tensor([[3.2443, 3.0472],
#         [3.0038, 2.5745]])
# tensor([[2.0693, 1.5336],
#         [1.4157, 0.2487]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251B7F64550>
# tensor([[4.2854, 4.2958],
#         [3.9989, 3.5768]])
# tensor([[4.8994, 4.9276],
#         [4.1206, 2.9732]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70BB700>
# tensor([[4.1281, 4.2327],
#         [3.6779, 3.0713]])
# tensor([[4.4718, 4.7561],
#         [3.2480, 1.5992]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B9D80>
# tensor([[3.7884, 3.1559],
#         [3.0121, 3.7521]])
# tensor([[3.5485, 1.8291],
#         [1.4381, 3.4498]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C70B9AB0>
# tensor([[3.2051, 3.0844],
#         [2.6890, 3.7994]])
# tensor([[1.9630, 1.6348],
#         [0.5600, 3.5784]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213E20>
# tensor([[3.1255, 2.8452],
#         [2.8806, 3.4061]])
# tensor([[1.7464, 0.9845],
#         [1.0809, 2.5093]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210DF0>
# tensor([[2.9512, 3.9215],
#         [3.0563, 2.9630]])
# tensor([[1.2727, 3.9102],
#         [1.5583, 1.3048]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7210DF0>
# tensor([[3.0107, 3.7076],
#         [3.9149, 3.6436]])
# tensor([[1.4344, 3.3289],
#         [3.8922, 3.1547]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72133D0>
# tensor([[3.0486, 4.2458],
#         [3.9797, 4.1979]])
# tensor([[1.5375, 4.7919],
#         [4.0685, 4.6615]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72133D0>
# tensor([[2.5757, 3.1389],
#         [4.1288, 3.6251]])
# tensor([[0.2519, 1.7830],
#         [4.4738, 3.1046]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72131F0>
# tensor([[3.6879, 4.2582],
#         [3.4439, 2.9995]])
# tensor([[3.2752, 4.8254],
#         [2.6119, 1.4039]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7213910>
# tensor([[2.9402, 2.8040],
#         [4.2595, 2.8903]])
# tensor([[1.2428, 0.8724],
#         [4.8289, 1.1071]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211AE0>
# tensor([[3.1082, 3.1132],
#         [3.2853, 4.0417]])
# tensor([[1.6994, 1.7130],
#         [2.1808, 4.2369]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C72126B0>
# tensor([[3.7846, 4.1454],
#         [3.3918, 4.1988]])
# tensor([[3.5381, 4.5188],
#         [2.4704, 4.6640]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EF605A80>
# tensor([[4.2974, 2.6763],
#         [3.9995, 3.0451]])
# tensor([[4.9321, 0.5254],
#         [4.1221, 1.5280]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EF607B20>
# tensor([[3.7128, 3.1166],
#         [4.2690, 3.4387]])
# tensor([[3.3428, 1.7224],
#         [4.8548, 2.5980]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2AA70>
# tensor([[3.9352, 3.8320],
#         [3.8691, 4.2685]])
# tensor([[3.9474, 3.6669],
#         [3.7677, 4.8535]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C707EDA0>
# tensor([[2.7560, 4.3222],
#         [2.7264, 3.9626]])
# tensor([[0.7421, 4.9996],
#         [0.6616, 4.0218]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C707CC40>
# tensor([[4.1487, 3.9762],
#         [2.7643, 3.9797]])
# tensor([[4.5278, 4.0589],
#         [0.7647, 4.0685]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C707DA20>
# tensor([[3.5163, 3.0733],
#         [3.8392, 2.9164]])
# tensor([[2.8089, 1.6045],
#         [3.6866, 1.1781]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7212AD0>
# tensor([[3.4924, 3.1893],
#         [3.8510, 2.8942]])
# tensor([[2.7438, 1.9199],
#         [3.7186, 1.1177]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4B80>
# tensor([[3.0666, 3.4101],
#         [3.0436, 3.7603]])
# tensor([[1.5864, 2.5200],
#         [1.5239, 3.4721]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4B80>
# tensor([[2.5167, 3.4902],
#         [3.2565, 2.4945]])
# tensor([[0.0915, 2.7378],
#         [2.1025, 0.0312]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4CD0>
# tensor([[3.8157, 3.4585],
#         [4.0673, 2.5106]])
# tensor([[3.6226, 2.6518],
#         [4.3066, 0.0749]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5150>
# tensor([[3.5756, 4.2829],
#         [3.0609, 2.6569]])
# tensor([[2.9700, 4.8927],
#         [1.5708, 0.4728]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B45B0>
# tensor([[2.9182, 2.6200],
#         [4.0288, 3.6999]])
# tensor([[1.1831, 0.3725],
#         [4.2019, 3.3079]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4B80>
# tensor([[2.9990, 4.0578],
#         [3.4619, 2.9487]])
# tensor([[1.4026, 4.2806],
#         [2.6609, 1.2658]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4CD0>
# tensor([[2.6606, 3.5037],
#         [3.4097, 3.7867]])
# tensor([[0.4828, 2.7746],
#         [2.5189, 3.5439]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5150>
# tensor([[2.9742, 2.5422],
#         [4.0945, 4.0068]])
# tensor([[1.3353, 0.1608],
#         [4.3805, 4.1422]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B45B0>
# tensor([[2.6061, 4.0521],
#         [2.6546, 3.5930]])
# tensor([[0.3347, 4.2654],
#         [0.4666, 3.0174]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4B80>
# tensor([[3.5693, 2.9241],
#         [3.1736, 3.2368]])
# tensor([[2.9529, 1.1991],
#         [1.8772, 2.0491]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4CD0>
# tensor([[4.3161, 4.1836],
#         [2.7702, 4.1716]])
# tensor([[4.9830, 4.6227],
#         [0.7806, 4.5900]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5150>
# tensor([[3.5164, 3.6728],
#         [4.1825, 2.9825]])
# tensor([[2.8091, 3.2341],
#         [4.6197, 1.3578]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B45B0>
# tensor([[3.2394, 3.3666],
#         [2.7559, 3.1856]])
# tensor([[2.0561, 2.4020],
#         [0.7418, 1.9099]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4B80>
# tensor([[4.0193, 3.6571],
#         [3.9723, 3.3540]])
# tensor([[4.1762, 3.1914],
#         [4.0484, 2.3677]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5630>
# tensor([[2.8246, 3.5755],
#         [2.4980, 2.5417]])
# tensor([[0.9284, 2.9698],
#         [0.0409, 0.1596]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7138F70>
# tensor([[3.3043, 4.1446],
#         [2.6788, 3.0433]])
# tensor([[2.2326, 4.5167],
#         [0.5322, 1.5231]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7138CA0>
# tensor([[3.4275, 3.9766],
#         [4.0975, 4.1801]])
# tensor([[2.5675, 4.0599],
#         [4.3886, 4.6132]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7138CA0>
# tensor([[3.4788, 3.0898],
#         [2.6061, 3.0022]])
# tensor([[2.7069, 1.6495],
#         [0.3347, 1.4113]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71382B0>
# tensor([[3.3140, 2.7971],
#         [3.8327, 3.9590]])
# tensor([[2.2589, 0.8539],
#         [3.6687, 4.0121]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71388B0>
# tensor([[4.2022, 2.8181],
#         [3.0235, 3.4410]])
# tensor([[4.6733, 0.9110],
#         [1.4693, 2.6040]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C713B6A0>
# tensor([[3.1693, 3.5986],
#         [3.3402, 3.8576]])
# tensor([[1.8655, 3.0325],
#         [2.3301, 3.7365]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7138CA0>
# tensor([[3.9506, 3.5555],
#         [4.0620, 3.5121]])
# tensor([[3.9894, 2.9154],
#         [4.2920, 2.7973]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71382B0>
# tensor([[4.1290, 3.6809],
#         [3.3746, 4.2244]])
# tensor([[4.4742, 3.2563],
#         [2.4237, 4.7337]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71388B0>
# tensor([[3.6431, 3.2526],
#         [3.7273, 3.6125]])
# tensor([[3.1536, 2.0921],
#         [3.3823, 3.0703]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7138CA0>
# tensor([[3.7169, 2.5026],
#         [2.5375, 3.3859]])
# tensor([[3.3540, 0.0534],
#         [0.1481, 2.4544]])
# <torch.utils.data.dataloader.DataLoader object at 0x000002509D863370>
# tensor([[3.3223, 3.8345],
#         [3.0981, 3.8004]])
# tensor([[2.2815, 3.6738],
#         [1.6720, 3.5812]])
# <torch.utils.data.dataloader.DataLoader object at 0x000002509D863370>
# tensor([[2.8081, 3.8747],
#         [3.7194, 4.1569]])
# tensor([[0.7602, 3.7829],
#         [3.2373, 4.5502]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE8FB910>
# tensor([[2.9306, 3.3624],
#         [2.7168, 4.1777]])
# tensor([[1.0935, 2.3904],
#         [0.5120, 4.6066]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128D90>
# tensor([[4.0543, 2.8907],
#         [2.9895, 3.5033]])
# tensor([[4.1498, 1.1083],
#         [1.2534, 2.7736]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128D90>
# tensor([[3.8649, 2.9102],
#         [3.8290, 2.9375]])
# tensor([[3.6347, 1.1613],
#         [3.5369, 1.2355]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C713B160>
# tensor([[3.6130, 3.5252],
#         [2.9379, 3.5205]])
# tensor([[2.9481, 2.8331],
#         [1.1131, 2.8201]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5DE0>
# tensor([[3.4608, 3.6380],
#         [3.8329, 2.7095]])
# tensor([[2.5343, 3.1396],
#         [3.5505, 0.6157]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B58D0>
# tensor([[2.8305, 3.2024],
#         [3.2437, 3.5974]])
# tensor([[0.8217, 1.9555],
#         [1.9443, 3.0291]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4CD0>
# tensor([[3.8768, 2.6655],
#         [2.7417, 4.2083]])
# tensor([[3.6708, 0.4960],
#         [0.5797, 4.6898]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EF607AF0>
# tensor([[4.0474, 3.9413],
#         [4.0055, 3.9312]])
# tensor([[4.1290, 3.9641],
#         [4.0149, 3.9365]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B5240>
# tensor([[4.2332, 3.1223],
#         [3.1709, 3.0075]])
# tensor([[4.6348, 1.7379],
#         [1.7475, 1.4256]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4940>
# tensor([[2.6371, 3.3499],
#         [2.5915, 2.5896]])
# tensor([[0.2957, 2.3564],
#         [0.1794, 0.2899]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7211660>
# tensor([[3.5012, 2.8932],
#         [2.8194, 3.4685]])
# tensor([[2.6464, 1.1151],
#         [0.7910, 2.6789]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4940>
# tensor([[3.8075, 2.6923],
#         [3.3281, 3.9473]])
# tensor([[3.4818, 0.5689],
#         [2.1737, 3.9805]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[3.2771, 3.7348],
#         [2.9119, 2.7742]])
# tensor([[2.0351, 3.4027],
#         [1.0458, 0.7916]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[3.5951, 3.6234],
#         [3.1608, 2.6710]])
# tensor([[2.8994, 3.0998],
#         [1.7244, 0.5110]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[2.9027, 2.8823],
#         [4.2434, 2.8027]])
# tensor([[1.0194, 1.0854],
#         [4.6649, 0.8690]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[3.8552, 3.8320],
#         [3.1860, 2.7363]])
# tensor([[3.6065, 3.6670],
#         [1.7915, 0.6885]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129FF0>
# tensor([[2.9684, 3.0749],
#         [4.1172, 3.9027]])
# tensor([[1.1968, 1.6091],
#         [4.3187, 3.8592]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[3.9404, 2.6626],
#         [4.2978, 2.7538]])
# tensor([[3.8439, 0.4881],
#         [4.8135, 0.7361]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[2.5519, 4.2058],
#         [4.3432, 2.8655]])
# tensor([[0.0636, 4.6829],
#         [4.9354, 1.0398]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[3.7655, 2.9508],
#         [3.1440, 3.9935]])
# tensor([[3.3642, 1.2715],
#         [1.6731, 4.1060]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129FF0>
# tensor([[3.1116, 3.0280],
#         [3.5942, 3.5347]])
# tensor([[1.5865, 1.4814],
#         [2.8970, 2.8588]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[4.0038, 4.1019],
#         [3.0531, 3.2621]])
# tensor([[4.0104, 4.4006],
#         [1.4267, 2.1179]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[3.3036, 3.9724],
#         [2.7341, 2.7747]])
# tensor([[2.1069, 4.0486],
#         [0.5625, 0.7929]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[3.1011, 4.1078],
#         [3.5119, 4.3043]])
# tensor([[1.5565, 4.4167],
#         [2.6732, 4.9507]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129FF0>
# tensor([[3.7391, 2.5442],
#         [2.7384, 2.6198]])
# tensor([[3.3006, 0.1663],
#         [0.5776, 0.3719]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[2.7324, 2.5893],
#         [4.1877, 3.9739]])
# tensor([[0.5623, 0.2889],
#         [4.5104, 4.0527]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[3.7837, 2.6051],
#         [3.8701, 3.5606]])
# tensor([[3.4195, 0.3319],
#         [3.6471, 2.9293]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[2.5923, 3.9452],
#         [3.1290, 2.6290]])
# tensor([[0.1736, 3.9747],
#         [1.6391, 0.3970]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129FF0>
# tensor([[3.2959, 2.6735],
#         [3.0237, 3.4580]])
# tensor([[2.0915, 0.5178],
#         [1.3463, 2.6503]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[3.8955, 3.0498],
#         [3.8647, 3.1357]])
# tensor([[3.7172, 1.5407],
#         [3.6331, 1.7743]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[2.8191, 4.2280],
#         [2.8527, 3.5277]])
# tensor([[0.7901, 4.7435],
#         [0.8816, 2.8398]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[3.7872, 2.7734],
#         [3.5622, 3.0634]])
# tensor([[3.4251, 0.7893],
#         [2.8110, 1.5777]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129FF0>
# tensor([[2.7427, 4.0139],
#         [3.0007, 2.6963]])
# tensor([[0.5822, 4.1615],
#         [1.2887, 0.5799]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7128AC0>
# tensor([[3.1364, 3.7101],
#         [3.4312, 4.2697]])
# tensor([[1.6525, 3.3355],
#         [2.4537, 4.8567]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[4.3183, 3.7828],
#         [3.9616, 3.1000]])
# tensor([[4.8654, 3.5333],
#         [3.8967, 1.6772]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF70>
# tensor([[3.1447, 4.2051],
#         [2.8045, 3.8593]])
# tensor([[1.6752, 4.6812],
#         [0.7504, 3.7412]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BF40>
# tensor([[4.0383, 2.7522],
#         [3.3625, 4.0505]])
# tensor([[4.1080, 0.7317],
#         [2.2671, 4.2609]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4E50>
# tensor([[3.6004, 3.7548],
#         [2.9152, 4.0045]])
# tensor([[2.9139, 3.4571],
#         [1.0511, 4.1358]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC707F0>
# tensor([[3.0707, 2.7529],
#         [3.8617, 4.1038]])
# tensor([[1.4779, 0.7336],
#         [3.6240, 4.4059]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC732B0>
# tensor([[4.1240, 2.7682],
#         [3.4079, 4.0616]])
# tensor([[4.3408, 0.7752],
#         [2.3906, 4.2911]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC732B0>
# tensor([[3.9142, 2.8225],
#         [3.9565, 2.9183]])
# tensor([[3.7697, 0.9229],
#         [3.8836, 1.1831]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC72590>
# tensor([[4.2052, 4.0996],
#         [3.0867, 3.1888]])
# tensor([[4.5578, 4.3943],
#         [1.5181, 1.9186]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC73D90>
# tensor([[3.5143, 4.1557],
#         [3.5492, 3.8267]])
# tensor([[2.6796, 4.5469],
#         [2.7745, 3.6525]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC728F0>
# tensor([[2.6274, 2.5923],
#         [2.8860, 2.9778]])
# tensor([[0.2768, 0.2972],
#         [0.9734, 1.3449]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC732B0>
# tensor([[2.6418, 2.5625],
#         [3.5359, 3.5617]])
# tensor([[0.3170, 0.2160],
#         [2.7387, 2.9323]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC72590>
# tensor([[3.3193, 3.3071],
#         [3.7144, 3.1202]])
# tensor([[2.1502, 2.2402],
#         [3.2245, 1.7320]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC73D90>
# tensor([[3.5388, 4.0038],
#         [3.7098, 4.2837]])
# tensor([[2.7463, 4.1340],
#         [3.2113, 4.8948]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC728F0>
# tensor([[3.8918, 3.0507],
#         [4.1049, 2.8979]])
# tensor([[3.7070, 1.5432],
#         [4.2872, 1.1277]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC732B0>
# tensor([[3.5799, 4.0542],
#         [4.0937, 3.0304]])
# tensor([[2.8581, 4.2710],
#         [4.2559, 1.4880]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC72590>
# tensor([[4.2787, 2.5060],
#         [2.8967, 3.7202]])
# tensor([[4.7693, 0.0626],
#         [1.0010, 3.3630]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC73D90>
# tensor([[2.6002, 3.3119],
#         [2.6675, 4.2550]])
# tensor([[0.1955, 2.2533],
#         [0.3778, 4.8168]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC728F0>
# tensor([[2.6666, 3.1654],
#         [3.5918, 2.9925]])
# tensor([[0.3762, 1.8550],
#         [2.8918, 1.3850]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC732B0>
# tensor([[3.5307, 2.9341],
#         [4.1935, 2.5974]])
# tensor([[2.7261, 1.2262],
#         [4.5338, 0.3110]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC728F0>
# tensor([[2.8337, 2.8576],
#         [2.6090, 4.0044]])
# tensor([[0.8321, 1.0183],
#         [0.2189, 4.1357]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC70850>
# tensor([[2.7858, 3.4305],
#         [2.9063, 2.8596]])
# tensor([[0.6996, 2.5755],
#         [1.0296, 1.0237]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC705B0>
# tensor([[3.6495, 4.0258],
#         [3.7147, 2.7748]])
# tensor([[3.0471, 4.1937],
#         [3.2282, 0.7932]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC73940>
# tensor([[2.8548, 4.2560],
#         [3.9812, 2.9056]])
# tensor([[0.8869, 4.8195],
#         [3.9508, 1.1487]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC73430>
# tensor([[3.7744, 3.3912],
#         [2.7812, 3.7524]])
# tensor([[3.3870, 2.4687],
#         [0.6870, 3.4505]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BD90>
# tensor([[3.1901, 4.1878],
#         [3.0460, 2.5525]])
# tensor([[1.7984, 4.6342],
#         [1.4162, 0.1890]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BCD0>
# tensor([[2.5459, 4.1588],
#         [2.8427, 3.8838]])
# tensor([[0.0475, 4.5552],
#         [0.8543, 3.8078]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BCD0>
# tensor([[2.9932, 2.6763],
#         [3.6955, 2.5139]])
# tensor([[1.2687, 0.5256],
#         [3.1834, 0.0839]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129930>
# tensor([[2.9686, 2.8532],
#         [4.1072, 3.0291]])
# tensor([[1.1990, 1.0063],
#         [4.2926, 1.4843]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7129C30>
# tensor([[2.8108, 3.0257],
#         [4.1924, 4.2753]])
# tensor([[0.7686, 1.4753],
#         [4.5230, 4.8720]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C712BDC0>
# tensor([[2.8976, 3.5168],
#         [4.0327, 3.0011]])
# tensor([[1.0035, 2.8101],
#         [4.0902, 1.4083]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71B4E50>
# tensor([[3.0395, 3.9675],
#         [3.9703, 2.7807]])
# tensor([[1.3890, 4.0352],
#         [3.9228, 0.8092]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5DB0>
# tensor([[3.7626, 2.8120],
#         [3.9544, 2.9234]])
# tensor([[3.3577, 0.8943],
#         [3.8780, 1.1970]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.6584, 3.0740],
#         [3.8057, 4.2378]])
# tensor([[3.0725, 1.6065],
#         [3.4719, 4.7701]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[2.8675, 3.6884],
#         [4.2244, 2.7005]])
# tensor([[0.9217, 3.2765],
#         [4.6149, 0.5913]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[2.6314, 2.6816],
#         [3.5650, 3.3548]])
# tensor([[0.2852, 0.5399],
#         [2.8179, 2.3698]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[2.9323, 4.0732],
#         [2.7948, 2.5973]])
# tensor([[1.0978, 4.3226],
#         [0.7318, 0.3107]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[3.2303, 3.5501],
#         [3.8002, 3.7236]])
# tensor([[1.9078, 2.9006],
#         [3.4570, 3.3723]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[2.9494, 2.4974],
#         [4.1753, 2.8947]])
# tensor([[1.1563, 0.0391],
#         [4.4786, 1.1191]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[4.1913, 3.8611],
#         [3.9554, 4.0508]])
# tensor([[4.5202, 3.7460],
#         [3.8787, 4.2616]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[4.0227, 4.1697],
#         [3.4994, 4.0181]])
# tensor([[4.0617, 4.5849],
#         [2.6394, 4.1728]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[3.4028, 3.7831],
#         [3.6859, 3.8732]])
# tensor([[2.3766, 3.5340],
#         [3.1463, 3.7790]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.2515, 4.1172],
#         [3.2260, 2.7453]])
# tensor([[1.9655, 4.4421],
#         [1.9003, 0.7130]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[3.0208, 2.5955],
#         [2.9465, 3.1989]])
# tensor([[1.3460, 0.3058],
#         [1.1369, 1.9461]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[3.1684, 2.9038],
#         [4.1828, 3.9706]])
# tensor([[1.7416, 1.1439],
#         [4.4970, 4.0437]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[4.3015, 3.4404],
#         [2.5544, 3.0385]])
# tensor([[4.8199, 2.6023],
#         [0.0718, 1.5101]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[4.2015, 2.8047],
#         [3.9099, 2.8540]])
# tensor([[4.5510, 0.8746],
#         [3.7576, 1.0084]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[4.3280, 2.7754],
#         [2.5391, 3.3909]])
# tensor([[4.8953, 0.7947],
#         [0.0290, 2.4680]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[2.7338, 3.8359],
#         [2.5480, 4.1470]])
# tensor([[0.5583, 3.6775],
#         [0.0532, 4.5231]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[4.3540, 2.5944],
#         [3.0521, 2.8879]])
# tensor([[4.9702, 0.3028],
#         [1.4256, 1.1006]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.4249, 4.0204],
#         [4.0850, 4.1545]])
# tensor([[2.4366, 4.1791],
#         [4.2312, 4.5437]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[2.6769, 2.8204],
#         [2.6390, 2.7683]])
# tensor([[0.4065, 0.9170],
#         [0.3042, 0.7756]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[4.2602, 3.0990],
#         [3.6912, 2.6392]])
# tensor([[4.7082, 1.6743],
#         [3.1670, 0.4246]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[4.2720, 4.1467],
#         [2.9152, 3.2054]])
# tensor([[4.7395, 4.5225],
#         [1.0519, 1.9635]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.3246, 2.6098],
#         [3.4764, 3.1043]])
# tensor([[2.1715, 0.3448],
#         [2.5776, 1.6888]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[3.0338, 2.5867],
#         [3.1315, 3.7895]])
# tensor([[1.3816, 0.2819],
#         [1.6391, 3.5514]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[3.0574, 3.5987],
#         [4.1612, 2.7372]])
# tensor([[1.4380, 3.0328],
#         [4.4425, 0.6909]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[3.1475, 3.1171],
#         [2.7104, 2.8857]])
# tensor([[1.6836, 1.7235],
#         [0.4969, 1.0947]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.1267, 2.6476],
#         [3.1709, 3.9164]])
# tensor([[1.6324, 0.4473],
#         [1.7462, 3.8965]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[4.2259, 2.6833],
#         [3.2739, 2.5975]])
# tensor([[4.6195, 0.5444],
#         [2.0339, 0.3112]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[3.9716, 4.2838],
#         [3.7062, 2.8338]])
# tensor([[3.9228, 4.8950],
#         [3.2041, 0.9536]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[3.3889, 3.9001],
#         [3.2398, 4.2869]])
# tensor([[2.3388, 3.8521],
#         [1.9336, 4.9034]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[3.2563, 3.3827],
#         [2.7207, 3.2175]])
# tensor([[1.9788, 2.4457],
#         [0.5232, 1.9965]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[3.3860, 4.1103],
#         [3.0593, 4.2279]])
# tensor([[2.3310, 4.4235],
#         [1.4430, 4.7433]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[3.1930, 3.0606],
#         [2.8119, 4.3201]])
# tensor([[1.8074, 1.5702],
#         [0.7703, 4.9939]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[3.0072, 3.5475],
#         [3.3891, 2.9073]])
# tensor([[1.3015, 2.8936],
#         [2.3415, 1.1534]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[1.6311, 3.5540],
#         [0.3504, 4.2955]])
# tensor([[3.9664, 2.9113],
#         [0.9048, 4.9270]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[1.1307, 3.3699],
#         [0.7062, 3.1205]])
# tensor([[2.2433, 2.4108],
#         [0.2871, 1.7328]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[0.4015, 4.0767],
#         [1.1759, 3.7098]])
# tensor([[1.0009, 4.3321],
#         [2.9129, 3.3347]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[1.9756, 2.5339],
#         [1.0696, 3.2453]])
# tensor([[1.3346, 0.1383],
#         [1.7197, 2.0722]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6CB0>
# tensor([[1.3959, 2.9007],
#         [1.5015, 4.2350]])
# tensor([[1.2529, 1.1354],
#         [4.0249, 4.7625]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA66B0>
# tensor([[2.4719, 2.5369],
#         [0.6959, 4.1388]])
# tensor([[2.6951, 0.1466],
#         [1.8165, 4.5010]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4580>
# tensor([[0.6627, 4.0515],
#         [1.4905, 2.6803]])
# tensor([[1.7038, 4.2636],
#         [0.5843, 0.5364]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[2.3450, 3.0194],
#         [1.2809, 2.6819]])
# tensor([[4.3355, 1.4580],
#         [0.0207, 0.5406]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5A50>
# tensor([[0.7576, 3.4141],
#         [0.3374, 3.4597]])
# tensor([[1.3337, 2.5310],
#         [0.2873, 2.6550]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[2.4374, 2.9925],
#         [1.6856, 3.3794]])
# tensor([[4.4741, 1.3848],
#         [3.7750, 2.4365]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[1.3267, 3.0427],
#         [1.6706, 4.2401]])
# tensor([[1.6639, 1.5215],
#         [4.4854, 4.7764]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[2.3704, 2.8354],
#         [0.6548, 3.9727]])
# tensor([[3.6227, 0.9580],
#         [1.6558, 4.0493]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[1.7337, 3.8759],
#         [1.7359, 2.8249]])
# tensor([[4.5451, 3.7862],
#         [1.8531, 0.9294]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[0.7419, 3.5645],
#         [2.3125, 2.8807]])
# tensor([[1.5649, 2.9398],
#         [3.6586, 1.0810]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[2.7708, 2.6633],
#         [1.2677, 3.6912]])
# tensor([[3.9957, 0.4900],
#         [3.1451, 3.2841]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[1.5357, 4.0510],
#         [2.4562, 2.5413]])
# tensor([[4.0766, 4.2623],
#         [2.6687, 0.1585]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[2.6071, 2.5153],
#         [0.6579, 3.0924]])
# tensor([[2.9831, 0.0879],
#         [0.0462, 1.6565]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[1.8747, 3.0964],
#         [2.6581, 2.6445]])
# tensor([[3.3698, 1.6674],
#         [3.6144, 0.4390]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[0.2212, 3.5872],
#         [2.1265, 2.5806]])
# tensor([[0.1812, 3.0015],
#         [1.9206, 0.2653]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[1.2870, 4.0198],
#         [1.8411, 3.9103]])
# tensor([[3.3909, 4.1775],
#         [4.8543, 3.8797]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[0.6589, 4.1636],
#         [0.6137, 3.2451]])
# tensor([[1.7213, 4.5682],
#         [0.4799, 2.0717]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[0.9786, 4.1709],
#         [1.4315, 2.8385]])
# tensor([[2.5916, 4.5882],
#         [1.0833, 0.9662]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[0.9820, 4.1403],
#         [1.0791, 3.1853]])
# tensor([[2.5945, 4.5050],
#         [1.5413, 1.9091]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[1.4450, 4.3169],
#         [2.1949, 3.1047]])
# tensor([[3.8832, 4.9849],
#         [4.2726, 1.6900]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[3.1247, 2.4940],
#         [2.6111, 2.7985]])
# tensor([[4.3126, 0.0298],
#         [4.1202, 0.8576]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[0.4282, 3.2938],
#         [2.4224, 2.8054]])
# tensor([[0.1265, 2.2039],
#         [3.6361, 0.8763]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[1.5367, 3.4584],
#         [2.1909, 3.0964]])
# tensor([[3.5446, 2.6515],
#         [4.2292, 1.6675]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[0.1997, 3.9310],
#         [0.8905, 3.2818]])
# tensor([[0.4017, 3.9359],
#         [1.3473, 2.1715]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[1.7489, 4.0324],
#         [2.4652, 2.4915]])
# tensor([[4.6507, 4.2116],
#         [2.5111, 0.0230]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[0.5619, 3.4721],
#         [2.1434, 3.0744]])
# tensor([[0.9216, 2.6887],
#         [4.0126, 1.6077]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[0.6471, 3.2840],
#         [1.4264, 4.1029]])
# tensor([[0.6924, 2.1774],
#         [3.7938, 4.4034]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA5660>
# tensor([[1.9797, 3.3122],
#         [1.1499, 3.3453]])
# tensor([[4.3973, 2.2541],
#         [2.2324, 2.3441]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA44F0>
# tensor([[0.5664, 4.2609],
#         [0.6073, 3.2688]])
# tensor([[1.4870, 4.8327],
#         [0.5377, 2.1360]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[1.0954, 3.3006],
#         [1.4045, 2.8246]])
# tensor([[1.9601, 2.2224],
#         [0.9511, 0.9287]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA72E0>
# tensor([[0.0355, 4.3038],
#         [2.5713, 2.6461]])
# tensor([[0.0501, 4.9493],
#         [3.3848, 0.4433]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA7C70>
# tensor([[2.6948, 2.6799],
#         [1.4125, 2.8254]])
# tensor([[3.8558, 0.5351],
#         [0.9759, 0.9306]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6500>
# tensor([[1.0727, 3.7544],
#         [0.6923, 3.5628]])
# tensor([[2.6701, 3.4560],
#         [1.4275, 2.9353]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[0.3222, 4.0620],
#         [0.6529, 3.6104]])
# tensor([[0.7814, 4.2922],
#         [1.3848, 3.0647]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[1.9205, 3.2124],
#         [3.2979, 2.4864]])
# tensor([[3.9232, 1.9828],
#         [4.7564, 0.0093]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[1.1004, 3.9209],
#         [1.5333, 2.9695]])
# tensor([[2.8456, 3.9086],
#         [1.9197, 1.3224]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA1090>
# tensor([[1.2798, 3.1420],
#         [0.7580, 3.5964]])
# tensor([[1.9282, 1.7914],
#         [1.6524, 3.0265]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA3520>
# tensor([[1.6686, 2.9369],
#         [0.9409, 3.7051]])
# tensor([[2.1485, 1.2337],
#         [2.2699, 3.3221]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[2.0322, 3.2962],
#         [1.2030, 4.0389]])
# tensor([[4.4936, 2.2105],
#         [3.1688, 4.2294]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[0.2626, 3.8196],
#         [1.6348, 3.8454]])
# tensor([[0.5139, 3.6333],
#         [4.2595, 3.7034]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA1090>
# tensor([[1.7047, 4.1494],
#         [2.2425, 2.7128]])
# tensor([[4.5610, 4.5296],
#         [2.7606, 0.6248]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA3520>
# tensor([[1.1568, 3.9185],
#         [0.3013, 4.0988]])
# tensor([[2.9979, 3.9021],
#         [0.7343, 4.3922]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[1.4205, 3.5460],
#         [0.5335, 4.1834]])
# tensor([[3.3820, 2.8894],
#         [1.3842, 4.6221]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[2.1222, 2.4974],
#         [1.5917, 4.0269]])
# tensor([[1.5998, 0.0391],
#         [4.2215, 4.1967]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA1090>
# tensor([[0.7070, 3.1913],
#         [1.2812, 2.7108]])
# tensor([[0.5509, 1.9253],
#         [0.1391, 0.6192]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA3520>
# tensor([[0.6091, 4.0575],
#         [0.0252, 4.2844]])
# tensor([[1.5599, 4.2798],
#         [0.0195, 4.8967]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[1.2030, 2.8167],
#         [0.5229, 3.4739]])
# tensor([[0.3695, 0.9071],
#         [0.8190, 2.6936]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[1.3090, 4.0934],
#         [1.4910, 3.4662]])
# tensor([[3.4722, 4.3776],
#         [3.4358, 2.6727]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA1090>
# tensor([[1.4208, 2.8830],
#         [0.2868, 3.7549]])
# tensor([[1.2446, 1.0873],
#         [0.5343, 3.4574]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA3520>
# tensor([[1.1242, 3.9142],
#         [1.4907, 3.6341]])
# tensor([[2.9072, 3.8905],
#         [3.6906, 3.1290]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[2.9413, 2.6606],
#         [0.7849, 3.0126]])
# tensor([[4.4485, 0.4829],
#         [0.0667, 1.4397]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[0.2297, 3.4851],
#         [1.6372, 3.0637]])
# tensor([[0.0426, 2.7238],
#         [2.5935, 1.5786]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA1090>
# tensor([[0.4597, 3.3139],
#         [1.0807, 3.3518]])
# tensor([[0.2703, 2.2586],
#         [2.0613, 2.3616]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA3520>
# tensor([[0.9925, 3.4225],
#         [0.1272, 4.0376]])
# tensor([[1.9906, 2.5537],
#         [0.2440, 4.2258]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[0.4551, 3.3418],
#         [1.8653, 4.0067]])
# tensor([[0.3343, 2.3344],
#         [4.9585, 4.1418]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[0.7856, 4.2105],
#         [1.2359, 2.7385]])
# tensor([[2.0745, 4.6959],
#         [0.1305, 0.6946]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA75B0>
# tensor([[0.4613, 3.4002],
#         [1.3974, 4.2091]])
# tensor([[0.4965, 2.4931],
#         [3.7374, 4.6919]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA48B0>
# tensor([[0.8386, 3.1869],
#         [1.7584, 3.1880]])
# tensor([[0.8933, 1.9134],
#         [3.3972, 1.9163]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA6500>
# tensor([[2.0945, 3.1812],
#         [0.2278, 4.1129]])
# tensor([[4.2866, 1.8978],
#         [0.5379, 4.4306]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA4BE0>
# tensor([[1.8592, 3.0683],
#         [1.8559, 3.1396]])
# tensor([[3.2151, 1.5909],
#         [3.4851, 1.7847]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0B80>
# tensor([[0.6624, 3.2919],
#         [1.4976, 3.3268]])
# tensor([[0.7574, 2.1987],
#         [3.1277, 2.2937]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[0.5750, 3.2809],
#         [0.3224, 3.6078]])
# tensor([[0.4868, 2.1688],
#         [0.4831, 3.0575]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[1.9736, 3.2614],
#         [1.0249, 3.0051]])
# tensor([[4.2283, 2.1159],
#         [0.6876, 1.4192]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0DF0>
# tensor([[0.6490, 3.5451],
#         [1.9676, 2.8851]])
# tensor([[1.2833, 2.8869],
#         [2.7403, 1.0931]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0640>
# tensor([[1.6072, 2.6963],
#         [1.9929, 2.9286]])
# tensor([[0.9660, 0.5797],
#         [2.9951, 1.2113]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA34C0>
# tensor([[0.5784, 3.9783],
#         [0.3221, 3.6504]])
# tensor([[1.4503, 4.0646],
#         [0.5326, 3.1733]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0700>
# tensor([[1.2802, 3.3640],
#         [2.5575, 2.9704]])
# tensor([[2.6349, 2.3947],
#         [4.7076, 1.3250]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0DF0>
# tensor([[0.2633, 3.7639],
#         [1.4904, 3.5078]])
# tensor([[0.4772, 3.4820],
#         [3.5099, 2.7856]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFCA0640>
# tensor([[1.8518, 3.9284],
#         [1.6643, 4.0124]])
# ...
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2A080>
# tensor([[3.0927, 3.7017],
#         [3.3857, 3.4345]])
# tensor([[1.5337, 3.3128],
#         [2.3304, 2.5863]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29FC0>
# tensor([[3.1189, 2.7156],
#         [4.1703, 2.4882]])
# tensor([[1.6095, 0.6323],
#         [4.4757, 0.0142]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2AC20>
# tensor([[3.1977, 3.6077],
#         [2.7463, 2.4893]])
# tensor([[1.8193, 3.0572],
#         [0.6046, 0.0171]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29DE0>
# tensor([[2.0132, 2.7327],
#         [1.2942, 2.8036]])
# tensor([[2.2191, 0.6786],
#         [0.5620, 0.8715]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29300>
# tensor([[1.5423, 4.1297],
#         [0.1150, 3.7451]])
# tensor([[4.1151, 4.4763],
#         [0.0594, 3.4307]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29C00>
# tensor([[0.5606, 3.3956],
#         [1.5040, 3.0098]])
# tensor([[0.7558, 2.4807],
#         [2.0096, 1.4320]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2B6D0>
# tensor([[1.4526, 2.9287],
#         [0.0751, 4.1186]])
# tensor([[1.5266, 1.2115],
#         [0.1245, 4.4460]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC28040>
# tensor([[0.5027, 4.0249],
#         [2.0820, 2.6777]])
# tensor([[1.2607, 4.1912],
#         [2.1815, 0.5293]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2A470>
# tensor([[1.0835, 3.1132],
#         [0.6182, 3.7264]])
# tensor([[1.2844, 1.7129],
#         [1.4115, 3.3798]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2BB20>
# tensor([[0.8858, 3.1584],
#         [2.5823, 3.0193]])
# tensor([[0.9182, 1.8358],
#         [4.9803, 1.4578]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29C60>
# tensor([[2.3241, 2.6504],
#         [1.6069, 3.5682]])
# tensor([[2.7301, 0.4550],
#         [3.9214, 2.9500]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2B4C0>
# tensor([[0.9703, 3.2525],
#         [1.1962, 3.8741]])
# tensor([[1.4728, 2.0916],
#         [3.0832, 3.7815]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2BE50>
# tensor([[1.3873, 3.4798],
#         [0.8897, 3.5336]])
# tensor([[3.1797, 2.7096],
#         [1.9197, 2.8559]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2BBE0>
# tensor([[0.7564, 4.1481],
#         [1.4851, 2.6386]])
# tensor([[1.9829, 4.5261],
#         [0.4023, 0.4228]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2ADA0>
# tensor([[0.5279, 3.7661],
#         [0.4815, 4.1397]])
# tensor([[1.1981, 3.4878],
#         [1.2340, 4.5032]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2A050>
# tensor([[1.6927, 2.5786],
#         [3.3514, 2.5113]])
# tensor([[0.7336, 0.2597],
#         [4.9917, 0.0770]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC28A00>
# tensor([[1.0202, 2.8979],
#         [1.7731, 3.2485]])
# tensor([[0.2195, 1.1277],
#         [3.6422, 2.0808]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC289D0>
# tensor([[0.7795, 4.0887],
#         [0.4957, 3.7111]])
# tensor([[2.0318, 4.3647],
#         [1.0651, 3.3384]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2AFB0>
# tensor([[0.2025, 3.5346],
#         [2.4779, 2.6801]])
# tensor([[0.0533, 2.8587],
#         [3.2673, 0.5358]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2BCD0>
# tensor([[1.5776, 3.2038],
#         [1.5438, 3.0964]])
# tensor([[2.9612, 1.9593],
#         [2.4701, 1.6674]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7216D10>
# tensor([[2.1664, 3.2060],
#         [1.8718, 2.6581]])
# tensor([[4.5694, 1.9653],
#         [1.5315, 0.4760]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7216D10>
# tensor([[1.6018, 3.7595],
#         [1.6041, 4.3111]])
# tensor([[4.1122, 3.4700],
#         [4.3149, 4.9692]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7217CD0>
# tensor([[1.5041, 2.8726],
#         [1.6556, 3.2984]])
# tensor([[1.4265, 1.0589],
#         [3.4764, 2.2164]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7217C40>
# tensor([[4.2481, 3.4742],
#         [3.3499, 3.9609]])
# tensor([[4.6746, 2.5707],
#         [2.2328, 3.8941]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7139210>
# tensor([[3.1226, 3.8003],
#         [2.9578, 2.5593]])
# tensor([[1.6152, 3.4582],
#         [1.1781, 0.0857]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3A710>
# tensor([[4.1272, 2.7517],
#         [2.5721, 3.9971]])
# tensor([[4.3506, 0.6068],
#         [0.1187, 4.0025]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3A710>
# tensor([[2.6939, 2.6051],
#         [3.8021, 3.3243]])
# tensor([[0.4586, 0.2143],
#         [3.4626, 2.1632]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2B220>
# tensor([[3.2352, 3.0773],
#         [3.1834, 3.3922]])
# tensor([[1.9223, 1.4924],
#         [1.7805, 2.3485]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29720>
# tensor([[3.9108, 3.1970],
#         [3.4090, 3.3939]])
# tensor([[3.7582, 1.8173],
#         [2.3938, 2.3529]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC29630>
# tensor([[3.7050, 3.3705],
#         [4.2286, 3.1693]])
# tensor([[3.1985, 2.2891],
#         [4.6222, 1.7419]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2ABC0>
# tensor([[3.2658, 4.1969],
#         [3.3636, 3.2089]])
# tensor([[2.0042, 4.5357],
#         [2.2707, 1.8500]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2AE60>
# tensor([[3.6352, 3.4644],
#         [3.0918, 3.4307]])
# tensor([[3.0086, 2.5442],
#         [1.5316, 2.4536]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC28A60>
# tensor([[3.4512, 3.4560],
#         [4.2339, 2.7683]])
# tensor([[2.5085, 2.5215],
#         [4.6400, 0.6519]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC28A60>
# tensor([[3.4093, 2.7940],
#         [3.6573, 3.7648]])
# tensor([[2.3981, 0.7221],
#         [3.0684, 3.3608]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2A680>
# tensor([[4.2370, 3.3993],
#         [4.2285, 3.9151]])
# tensor([[4.6447, 2.3673],
#         [4.6211, 3.7691]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC28A60>
# tensor([[3.9711, 2.7834],
#         [3.3153, 2.8854]])
# tensor([[3.9256, 0.6931],
#         [2.1414, 0.9706]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C7277250>
# tensor([[2.6135, 2.9485],
#         [3.3247, 4.0138]])
# tensor([[0.2331, 1.1504],
#         [2.1644, 4.0379]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250917BC7C0>
# tensor([[3.8736, 3.0872],
#         [3.4812, 2.8571]])
# tensor([[3.6574, 1.5188],
#         [2.5927, 0.8935]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250917745E0>
# tensor([[3.4714, 2.8224],
#         [3.4728, 3.9303]])
# tensor([[2.5667, 0.7993],
#         [2.5669, 3.8107]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC2B220>
# tensor([[3.5819, 2.7536],
#         [3.5797, 3.0801]])
# tensor([[2.8683, 0.6122],
#         [2.8588, 1.4996]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC398A0>
# tensor([[2.8899, 3.7597],
#         [4.2030, 2.9412]])
# tensor([[0.9825, 3.3494],
#         [4.5538, 1.1220]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[3.2761, 4.0594],
#         [4.2157, 2.5795]])
# tensor([[2.0322, 4.1621],
#         [4.5964, 0.1387]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[2.6111, 3.5652],
#         [2.7324, 4.0569]])
# tensor([[0.2247, 2.8269],
#         [0.5545, 4.1598]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC38DC0>
# tensor([[3.7542, 1.3393],
#         [3.8447, 0.3084]])
# tensor([[3.3351, 3.3716],
#         [3.6320, 0.6449]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC395A0>
# tensor([[4.0194, 1.8232],
#         [2.6810, 2.7466]])
# tensor([[4.0537, 4.8397],
#         [0.4148, 3.9056]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC381F0>
# tensor([[3.8933, 0.1384],
#         [4.1377, 0.2234]])
# tensor([[3.7993, 0.2139],
#         [4.4401, 0.5295]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[3.5101, 1.9535],
#         [3.8896, 0.3995]])
# tensor([[2.6691, 4.7178],
#         [3.7407, 0.9167]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC38DC0>
# tensor([[2.8353, 1.5472],
#         [2.5352, 2.1185]])
# tensor([[0.8383, 1.2759],
#         [0.0198, 1.6500]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC395A0>
# tensor([[3.7674, 1.0810],
#         [3.9464, 0.4669]])
# tensor([[3.3742, 2.6813],
#         [3.8877, 1.1269]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC381F0>
# tensor([[4.2219, 0.7902],
#         [3.6304, 1.3788]])
# tensor([[4.6165, 2.0857],
#         [2.9985, 3.3461]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[3.1768, 1.8956],
#         [3.1921, 1.0291]])
# tensor([[1.7634, 3.6184],
#         [1.8141, 1.3283]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC38DC0>
# tensor([[4.1811, 1.8303],
#         [3.8593, 0.5289]])
# tensor([[4.4932, 4.9042],
#         [3.6460, 1.2497]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC395A0>
# tensor([[2.5758, 2.2049],
#         [4.3428, 1.1704]])
# tensor([[0.1297, 2.0326],
#         [4.9368, 3.1373]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC381F0>
# tensor([[3.4885, 2.0636],
#         [3.1653, 1.0889]])
# tensor([[2.6102, 4.9750],
#         [1.7399, 1.3904]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[4.2065, 1.3265],
#         [3.6380, 1.9792]])
# tensor([[4.5647, 3.5400],
#         [3.0166, 4.9872]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC38DC0>
# tensor([[3.7932, 0.2833],
#         [2.9488, 2.5680]])
# tensor([[3.4972, 0.5429],
#         [1.1428, 4.5245]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC395A0>
# tensor([[3.8108, 0.8750],
#         [3.5694, 1.5387]])
# tensor([[3.4967, 2.1558],
#         [2.8316, 3.6929]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC381F0>
# tensor([[3.4092, 0.8199],
#         [2.6040, 2.6983]])
# tensor([[2.4091, 1.4285],
#         [0.2055, 3.4783]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BB80>
# tensor([[3.1629, 0.7342],
#         [3.9668, 1.8395]])
# tensor([[1.7512, 0.4317],
#         [3.9108, 4.8632]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC38DC0>
# tensor([[3.0554, 1.5449],
#         [4.0011, 0.3505]])
# tensor([[1.4350, 2.1905],
#         [4.0491, 0.8336]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC381F0>
# tensor([[4.3581, 1.5797],
#         [3.3517, 2.0742]])
# tensor([[4.9752, 4.2517],
#         [2.2382, 4.6772]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3B3D0>
# tensor([[4.3278, 0.6183],
#         [4.0656, 0.1793]])
# tensor([[4.9119, 1.6350],
#         [4.2545, 0.3914]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3A500>
# tensor([[2.5788, 2.2684],
#         [3.4396, 1.6876]])
# tensor([[0.1377, 2.2162],
#         [2.4783, 3.8496]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3A9B0>
# tensor([[0.7147, 3.8130],
#         [2.2676, 2.1213]])
# tensor([[1.8043, 4.5323],
#         [4.5331, 4.3924]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3B220>
# tensor([[0.6221, 3.2305],
#         [2.3971, 1.8473]])
# tensor([[0.7287, 2.4048],
#         [3.9575, 3.5669]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3BEE0>
# tensor([[3.0357, 1.2992],
#         [1.4300, 2.4120]])
# tensor([[4.2279, 2.9262],
#         [0.5821, 1.1232]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000250EFC3B100>
# tensor([[1.5383, 2.4392],
#         [3.5666, 0.1928]])
# tensor([[1.6323, 1.9881],
#         [2.9981, 0.0943]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84F700>
# tensor([[0.7046, 3.8189],
#         [2.6157, 1.2667]])
# tensor([[1.7779, 4.5197],
#         [1.5656, 0.8964]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84D6C0>
# tensor([[2.2863, 1.9229],
#         [3.2994, 1.2052]])
# tensor([[3.7337, 3.4953],
#         [4.8260, 2.9462]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84D6C0>
# tensor([[3.4891, 0.8530],
#         [0.4437, 3.6336]])
# tensor([[3.9557, 2.0075],
#         [0.9032, 3.4129]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84D5D0>
# tensor([[2.7611, 1.2684],
#         [3.2225, 0.5388]])
# tensor([[2.5144, 1.8595],
#         [2.2617, 0.4061]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84CC70>
# tensor([[2.0853, 2.3900],
#         [3.4621, 1.0301]])
# tensor([[4.5906, 4.9212],
#         [4.6007, 2.5350]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84FE80>
# tensor([[3.4336, 1.0693],
#         [3.0133, 0.8356]])
# tensor([[4.6779, 2.6340],
#         [2.0284, 0.7748]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84D6C0>
# tensor([[1.1776, 3.0180],
#         [0.7457, 3.3806]])
# tensor([[2.4006, 3.4843],
#         [1.5188, 3.2106]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84D5D0>
# tensor([[2.9590, 1.0333],
#         [0.7857, 3.2242]])
# tensor([[2.4315, 1.4940],
#         [1.3265, 2.7395]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84CC70>
# tensor([[1.0386, 3.2036],
#         [3.0185, 1.3048]])
# tensor([[2.2534, 3.6393],
#         [4.1797, 2.9158]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84FE80>
# tensor([[0.5429, 4.0924],
#         [0.7736, 3.3502]])
# tensor([[1.4050, 4.9086],
#         [1.5621, 3.1823]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251BE84C070>
# tensor([[2.3700, 1.4664],
#         [3.7400, 0.1414]])
# tensor([[1.0448, 0.5373],
#         [3.4574, 0.1346]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71D4760>
# tensor([[1.2276, 2.8342],
#         [2.3116, 1.8052]])
# tensor([[1.9902, 2.7352],
#         [3.1287, 2.8790]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71D5390>
# tensor([[1.8242, 1.9610],
#         [4.1777, 0.0343]])
# tensor([[0.2830, 0.3747],
#         [4.6139, 0.0266]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71D5390>
# tensor([[3.1481, 0.6738],
#         [1.3264, 2.4331]])
# tensor([[2.2062, 0.6473],
#         [0.0892, 0.8327]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71D4310>
# tensor([[2.9957, 1.4102],
#         [2.5435, 1.6981]])
# tensor([[4.6206, 3.2665],
#         [3.9467, 3.3633]])
# <torch.utils.data.dataloader.DataLoader object at 0x00000251C71D4A30>
# tensor([[0.5781, 3.6313],
#         [0.6215, 3.7501]])
# tensor([[1.2981, 3.6299],
#         [1.5075, 4.0889]])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[256, 1], edge_index=[2, 64], y=[32], batch=[256], ptr=[33])
# DataBatch(x=[192, 1], edge_index=[2, 48], y=[24], batch=[192], ptr=[25])

# %%
class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GATConv(-1, 16)
        self.conv2 = GATConv(16, 2)
        self.linear = torch.nn.Linear(2, 6)  # Linear layer to output 6x1 vector


    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        # Here we aggregate the output from all nodes
        x = x.mean(dim=0, keepdim=True)
        x = self.linear(x)

        return F.log_softmax(x, dim=1)

# %%
class fullnet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = torch.nn.Linear(8, 10)  # Linear layer to output 6x1 vector
        self.linear2 = torch.nn.Linear(10, 10)  # Linear layer to output 6x1 vector
        self.linear3 = torch.nn.Linear(10, 10)  # Linear layer to output 6x1 vector
        self.linear4 = torch.nn.Linear(10, 6)  # Linear layer to output 6x1 vector

    def forward(self, data):
        x = data.x  # x should be of shape [batch_size, num_features]
        
        # Forward pass through the layers
        x = self.linear(x.t())
        x = torch.relu(x)  # Apply activation
        x = self.linear2(x)
        x = torch.relu(x)
        x = self.linear3(x)
        x = torch.relu(x)
        x = self.linear4(x)  # No activation on the final layer

        return F.log_softmax(x, dim=1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN().to(device)
data = data_list[0].to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)

model.train()
for epoch in range(200):
    loss = 0
    for data_point in data_list:
        data = data_point.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = loss + F.nll_loss(out, data.y)
    loss.backward()
    optimizer.step()
    print(loss)
# Out:
# tensor(1138.7319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1201.0927, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1101.0800, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1086.5620, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1097.5685, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1085.9463, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1077.5461, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1075.3191, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1075.8744, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1077.8876, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1078.7294, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1078.5189, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1078.9410, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1077.9056, device='cuda:0', grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[122], line 14
#      12     out = model(data)
#      13     loss = loss + F.nll_loss(out, data.y)
# ---> 14 loss.backward()
#      15 optimizer.step()
#      16 print(loss)
#
# File c:\Users\Lucas\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\Lucas\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = fullnet().to(device)
data = data_list[0].to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

model.train()
for epoch in range(200):
    loss = 0
    for data_point in data_list:
        data = data_point.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = loss + F.nll_loss(out, data.y)
    loss.backward()
    optimizer.step()
    print(loss)
# Out:
# tensor(1090.9359, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1087.6859, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1085.0284, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1082.7002, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1080.6356, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1078.8340, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1077.1315, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1075.5056, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1073.9006, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1072.2570, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1070.7252, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1068.9974, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1066.6732, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1063.9330, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1061.0620, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1057.8567, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1053.8810, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1048.6329, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1042.1425, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1034.3655, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1025.1373, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1013.9761, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1000.7346, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(985.8904, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(968.6323, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(948.5556, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(925.6553, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(900.1005, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(872.6367, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(843.8024, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(812.9911, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(780.7363, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(748.3171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(717.0759, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(687.3083, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(658.5483, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(631.5363, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(607.2661, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(586.2365, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(568.2290, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(552.1605, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(536.8613, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(522.5798, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(509.2528, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(496.7135, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(484.7096, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(472.1811, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(458.6396, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(444.4645, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(430.6611, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(417.9864, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(405.6043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(397.8797, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(405.9623, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(381.7476, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(391.7773, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(379.3101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(380.6498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(365.4661, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(375.2240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(362.6162, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(361.4154, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(365.4029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(358.4740, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(357.1965, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(360.6248, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(354.8458, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(354.3870, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(356.4688, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(351.4949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(352.2824, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(352.2301, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(349.7426, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(349.8477, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(350.0150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(347.6295, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(347.8747, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(347.8035, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.8704, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.6730, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.6883, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(344.6838, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(344.2395, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(344.2926, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(343.1114, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.5366, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.9593, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.7334, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.8327, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.3199, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.7308, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.8638, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.2293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(338.9337, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(338.5030, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.3340, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(366.1923, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(427.1507, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(344.7436, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(395.9350, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.3097, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(380.2386, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.4061, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(361.4383, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(355.5154, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.1971, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(356.6509, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(349.4472, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.1212, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(349.2106, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(348.2703, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.3091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.3565, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(345.3383, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.4578, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(344.5445, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(343.2389, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.4256, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(343.0034, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(342.2233, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.5258, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(341.2433, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.3878, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.3175, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.1078, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(338.5463, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(338.5899, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.4009, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(337.3233, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(337.7898, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(337.8210, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(336.6698, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(337.1990, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(336.0605, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(335.9055, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(336.1606, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(335.0341, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(335.2748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(334.5098, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(334.5225, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(333.9734, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(333.5751, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(333.3485, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(332.8563, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(332.8017, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(332.0181, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(332.0961, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(331.4890, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(331.4142, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(330.7823, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(330.8231, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(330.1695, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(329.9400, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(329.5081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(329.0593, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(329.0896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(328.3003, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(328.0500, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(327.9482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(327.2472, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(326.8686, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(326.6843, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(326.3244, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(325.8203, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(325.2906, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(324.8498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(324.6596, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(325.2243, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(328.6603, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(339.3474, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(360.7790, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(355.1294, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(331.7278, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(324.9654, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.9109, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(340.3771, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(323.1589, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(330.2774, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(334.4793, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(323.3370, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(327.3158, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(330.1314, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(322.1796, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(325.2624, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(328.6042, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(321.7252, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(323.7345, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(326.8457, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(321.4185, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(321.0948, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(324.7218, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(322.8091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(319.2695, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(320.7035, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(323.7023, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(322.5627, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(318.9953, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(317.7555, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(319.9054, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(322.7986, device='cuda:0', grad_fn=<AddBackward0>)

# %%
correct = 0
total = 0
for data_point in test_data_list:
    data = data_point.to(device)
    out = model(data)
    loss = F.nll_loss(out, data.y)
    pred = torch.argmax(out)
    if pred == data.y[0]:
        correct = correct + 1
    total = total + 1

print(correct/total)
# Out:
# 0.6666666666666666
