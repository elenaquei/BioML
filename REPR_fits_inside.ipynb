# %%
import torch
device = 'cpu'
import matplotlib.pyplot as plt
import numpy as np
from models.training import create_dataloader
import scipy.io as io


# Juptyer magic: For export. Makes the plots size right for the screen 
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %config InlineBackend.figure_formats = ['svg'] 

torch.backends.cudnn.deterministic = True
seed = np.random.randint(1,200)
seed = 56
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
print(seed)
g = torch.Generator()
g.manual_seed(seed)

# design choices 
chosen_problem = 'repr_alt'
data_noise = 0.
n_different_weights = 1
if n_different_weights == 1:
    print('This choice will generate autonomous dynamics')
else:
    print('This choice generates non-autonomous dynamics, letting the weights depend on time')

possible_problem = {'moons':'moons', 'ToggleSwitch':'TS', 'repressilator':'repr', 'restricted_TS': 'restrictedTS','repr_alt':'repr_alt'} 
# this choices determine the data set that we build and subsequent choices on the construction of the neural ODE 
# - in particular, it determines the dimensions 
problem = possible_problem[chosen_problem]

plotlim = [0, 5]
# Out:
# 56
# This choice will generate autonomous dynamics

# %%
ind = 0
m1vec = []
m2vec = []
lossvec = []
var1vec = []
var2vec = []
for sz in range(2,11):

    m1vectemp = []
    m2vectemp = []
    lossvectemp = []
    Xtempvec = []
    W1vec = []

    for k in range(0,50):
        
        ind = ind + 1
        seed = ind

        dataloader, dataloader_viz, X_train = create_dataloader(problem, batch_size = sz, noise = data_noise, 
                                                    plotlim = plotlim, random_state = seed, label = 'vector')
        
        print(k)
        print(X_train.detach().numpy())

        #Import of the model dynamics that describe the neural ODE
        #The dynamics are based on the torchdiffeq package, that implements ODE solvers in the pytorch setting
        from models.neural_odes import NeuralODE

        #T is the end time of the neural ODE evolution, num_steps are the amount of discretization steps for the ODE solver
        T, num_steps = 1, n_different_weights
        bound = 0.
        fp = False
        cross_entropy = False
        turnpike = False

        # choice of model: what nonlinearity is used and if the nonlinearity is applied before (inside) or after (outside) the linear weights
        # another choice is bottleneck, but I don't understand it
        # non_linearity = 'tanh' # OR 'relu' 'sigmoid' 'leakyrelu' 'tanh_prime'
        # architecture = 'inside' 'outside'
        non_linearity = 'tanh'
        architecture = 'inside'
        architectures = {'inside': -1, 'outside': 0, 'bottleneck': 1, 'restricted': 2, 'restr_repr':3}
        # number of optimization runs in which the dataset is used for gradient decent
        num_epochs = 50
        if problem == 'moons' or problem == 'TS' or problem == "restrictedTS":
            hidden_dim, data_dim = 2, 2 
        else:
            hidden_dim, data_dim = 3, 3 
        augment_dim = 0

        # resets the seed - allows for coherent runs in the gradient descent as well
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        anode = NeuralODE(device, data_dim, hidden_dim, output_dim=data_dim, augment_dim=augment_dim, non_linearity=non_linearity, 
                            architecture=architecture, T=T, time_steps=num_steps, fixed_projector=fp, cross_entropy=cross_entropy)
        optimizer_anode = torch.optim.Adam(anode.parameters(), lr=1e-1)

        from models.training import doublebackTrainer

        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        trainer_anode = doublebackTrainer(anode, optimizer_anode, device, cross_entropy=cross_entropy, turnpike = turnpike,
                                bound=bound, fixed_projector=fp, verbose = False, eps_comp = 0.2)

        trainer_anode.train(dataloader, 400)

        W1 = anode.flow.dynamics.fc2_time[0].weight
        W1 = W1.detach().numpy()
        m1 = abs(W1[0][1]-W1[1][0])
        m2 = abs(W1[0][0])+abs(W1[1][1])

        lv = trainer_anode.histories["loss_history"]
        l = lv[-1]

        m1vectemp.append(m1)
        m2vectemp.append(m2)
        lossvectemp.append(l)
        Xtempvec.append(X_train.detach().numpy())
        W1vec.append(W1)
    
    mdic = {"X":Xtempvec,"l":lossvectemp,"symm":m1vectemp,"offdiag":m2vectemp,"W1":W1vec}
    io.savemat("repr_inside_n"+str(sz)+".mat",mdic)
    m1vec.append(np.mean(m1vectemp))
    m2vec.append(np.mean(m2vectemp))
    lossvec.append(np.mean(lossvectemp))
    var1vec.append(np.var(m1vectemp))
    var2vec.append(np.var(m2vectemp))
# Out:
# No change  applied to TS or repr data
# 0
# [[4.765574  2.803489  1.7676971]
#  [4.7275352 2.338076  3.640512 ]]
# inside
# No change  applied to TS or repr data
# 1
# [[3.788158   1.3965545  2.0153463 ]
#  [3.6734223  0.14640778 3.999293  ]]
# inside
# No change  applied to TS or repr data
# 2
# [[3.0734754 1.9050643 3.1855717]
#  [2.3723054 3.5679693 3.095182 ]]
# inside
# No change  applied to TS or repr data
# 3
# [[0.0213176  0.5278468  1.4292123 ]
#  [0.13477415 2.3580718  0.30058146]]
# inside
# No change  applied to TS or repr data
# 4
# [[2.798193   2.7954621  0.45728415]
#  [1.0500159  0.03597289 0.19480944]]
# inside
# No change  applied to TS or repr data
# 5
# [[4.1512594  0.63055456 4.5373483 ]
#  [4.099635   4.6005173  0.5832261 ]]
# inside
# No change  applied to TS or repr data
# 6
# [[2.8609877 2.7693775 4.9341497]
#  [3.040148  1.1732799 2.2458973]]
# inside
# No change  applied to TS or repr data
# 7
# [[2.6746128  0.99401593 3.2960584 ]
#  [3.2844515  1.1638079  2.125307  ]]
# inside
# No change  applied to TS or repr data
# 8
# [[2.9896364 4.2264805 4.7320514]
#  [1.4826515 2.5690093 3.2217293]]
# inside
# No change  applied to TS or repr data
# 9
# [[3.2789226 1.5101135 2.3994823]
#  [3.886868  4.589822  4.655168 ]]
# inside
# No change  applied to TS or repr data
# 10
# [[2.2904232 2.4142828 1.5624917]
#  [3.0751083 1.0697365 2.059131 ]]
# inside
# No change  applied to TS or repr data
# 11
# [[0.74520856 2.4327657  4.9283075 ]
#  [0.8420071  2.919717   3.467996  ]]
# inside
# No change  applied to TS or repr data
# 12
# [[2.3284373 1.1638341 2.263605 ]
#  [2.9355612 2.0432236 0.6358725]]
# inside
# No change  applied to TS or repr data
# 13
# [[0.4590851  2.396903   4.0527563 ]
#  [0.07553577 0.07651508 3.017836  ]]
# inside
# No change  applied to TS or repr data
# 14
# [[2.8474746  0.02360106 4.651264  ]
#  [3.6286612  4.147436   3.8414743 ]]
# inside
# No change  applied to TS or repr data
# 15
# [[1.4866471 1.382977  3.9867818]
#  [1.9343963 4.58492   2.0624924]]
# inside
# No change  applied to TS or repr data
# 16
# [[0.8125809  3.119883   4.649084  ]
#  [1.27947    4.897862   0.02948612]]
# inside
# No change  applied to TS or repr data
# 17
# [[2.1712062  2.6755478  4.1510434 ]
#  [0.6193179  0.14660537 2.7469804 ]]
# inside
# No change  applied to TS or repr data
# 18
# [[2.4790316 2.2937832 1.9803214]
#  [3.7606254 4.6098895 3.0224373]]
# inside
# No change  applied to TS or repr data
# 19
# [[4.8430147  0.9993309  4.3996396 ]
#  [3.3109574  1.0806012  0.59601396]]
# inside
# No change  applied to TS or repr data
# 20
# [[2.8074179 0.8869821 4.073567 ]
#  [1.6477106 1.159333  3.9157753]]
# inside
# No change  applied to TS or repr data
# 21
# [[2.3678424  3.0679939  0.0603652 ]
#  [0.19798398 2.8369284  1.2690306 ]]
# inside
# No change  applied to TS or repr data
# 22
# [[1.8294873  3.5126126  1.5517557 ]
#  [0.04850388 3.2886803  0.97331226]]
# inside
# No change  applied to TS or repr data
# 23
# [[2.1412907 1.4443129 2.1121335]
#  [1.7852619 4.7884912 0.549767 ]]
# inside
# No change  applied to TS or repr data
# 24
# [[3.822146   1.875268   0.37542343]
#  [2.6539109  4.830137   1.3849308 ]]
# inside
# No change  applied to TS or repr data
# 25
# [[3.7588894  0.96445024 0.31447232]
#  [4.5587583  1.9138517  1.495015  ]]
# inside
# No change  applied to TS or repr data
# 26
# [[4.1567388 2.7823825 4.8210926]
#  [2.4931097 3.4210017 0.9549254]]
# inside
# No change  applied to TS or repr data
# 27
# [[4.9234066  0.42592764 2.6671815 ]
#  [1.0981843  1.3085341  3.9858198 ]]
# inside
# No change  applied to TS or repr data
# 28
# [[3.1375887  3.6535623  3.3866897 ]
#  [3.6905737  4.957882   0.23652077]]
# inside
# No change  applied to TS or repr data
# 29
# [[0.61278015 4.67754    4.679636  ]
#  [3.5188284  3.768168   1.7092252 ]]
# inside
# No change  applied to TS or repr data
# 30
# [[4.503719  3.7318149 2.3580685]
#  [4.3688335 3.701321  3.9200246]]
# inside
# No change  applied to TS or repr data
# 31
# [[1.1488968 2.1092484 1.3751268]
#  [2.5863261 1.000548  2.637832 ]]
# inside
# No change  applied to TS or repr data
# 32
# [[4.3782682  1.3603339  2.0702758 ]
#  [3.9286203  0.56484103 2.896709  ]]
# inside
# No change  applied to TS or repr data
# 33
# [[3.0929625 2.7936957 0.9685397]
#  [1.6798598 1.0042244 3.484862 ]]
# inside
# No change  applied to TS or repr data
# 34
# [[4.35895    0.5777341  3.5285883 ]
#  [1.9207313  3.6608095  0.05953461]]
# inside
# No change  applied to TS or repr data
# 35
# [[1.3103321  0.7376906  4.6874943 ]
#  [0.94999045 1.3034155  0.01677871]]
# inside
# No change  applied to TS or repr data
# 36
# [[2.4892058  2.177916   0.06619394]
#  [2.5546002  3.7912467  0.69129765]]
# inside
# No change  applied to TS or repr data
# 37
# [[3.9556549 3.2093368 4.045662 ]
#  [0.8295426 1.7776382 3.0946126]]
# inside
# No change  applied to TS or repr data
# 38
# [[2.5095847 3.1725535 0.4260412]
#  [3.8517628 3.5755336 2.5191891]]
# inside
# No change  applied to TS or repr data
# 39
# [[0.01812249 2.2534492  1.3107421 ]
#  [1.7679024  0.11440873 4.618704  ]]
# inside
# No change  applied to TS or repr data
# 40
# [[1.8393916  4.3305097  0.86853236]
#  [3.5785403  4.3246436  2.4387908 ]]
# inside
# No change  applied to TS or repr data
# 41
# [[1.1822319 1.13309   4.002651 ]
#  [0.8459383 1.3247919 3.859959 ]]
# inside
# No change  applied to TS or repr data
# 42
# [[4.4113464 4.57502   1.9143188]
#  [4.7965283 1.9522411 3.0044768]]
# inside
# No change  applied to TS or repr data
# 43
# [[2.2698414  0.9824562  4.6051784 ]
#  [1.7308953  0.740439   0.42909443]]
# inside
# No change  applied to TS or repr data
# 44
# [[3.5979521  3.6533842  4.1390185 ]
#  [0.67174345 3.1398187  3.6486444 ]]
# inside
# No change  applied to TS or repr data
# 45
# [[0.9347376 4.806642  3.417245 ]
#  [4.4939795 0.2525425 2.7772806]]
# inside
# No change  applied to TS or repr data
# 46
# [[3.3054152  0.29993206 2.5871396 ]
#  [0.79814553 3.775156   4.1950665 ]]
# inside
# No change  applied to TS or repr data
# 47
# [[0.265238   0.24959743 2.3383543 ]
#  [4.3784356  2.7803254  3.9919052 ]]
# inside
# No change  applied to TS or repr data
# 48
# [[2.3875427  0.89921564 1.2137845 ]
#  [1.0832036  4.622296   3.034339  ]]
# inside
# No change  applied to TS or repr data
# 49
# [[0.23450196 1.3835659  1.23914   ]
#  [4.633633   0.7089776  3.5961115 ]]
# inside
# No change  applied to TS or repr data
# 0
# [[3.0901098  0.3434658  1.9463763 ]
#  [0.20205885 2.0066168  0.72081506]
#  [2.3022854  2.4383755  2.963325  ]]
# inside
# No change  applied to TS or repr data
# 1
# [[4.936218  3.7017992 2.2315898]
#  [1.7778683 4.4286947 1.6850867]
#  [4.34525   1.1608567 3.7926383]]
# inside
# No change  applied to TS or repr data
# 2
# [[3.5812345 3.9189613 3.4310184]
#  [2.204441  4.786422  3.475978 ]
#  [1.5798652 4.641263  0.8041096]]
# inside
# No change  applied to TS or repr data
# 3
# [[3.7278821 3.8063898 3.2918897]
#  [3.21973   2.2405229 3.5019484]
#  [0.7838887 1.1439478 4.889774 ]]
# inside
# No change  applied to TS or repr data
# 4
# [[2.8342006 3.234655  4.9465566]
#  [3.2213638 1.6421578 4.1295533]
#  [3.4018898 2.4387527 1.0149786]]
# inside
# No change  applied to TS or repr data
# 5
# [[4.178604   4.688919   3.7195704 ]
#  [2.8372025  4.340781   2.3823633 ]
#  [0.42905718 3.8702312  4.838502  ]]
# inside
# No change  applied to TS or repr data
# 6
# [[4.765574  2.803489  1.7676971]
#  [4.7275352 2.338076  3.640512 ]
#  [1.3797361 2.3671384 3.6914756]]
# inside
# No change  applied to TS or repr data
# 7
# [[1.8075416  3.2848234  0.01068264]
#  [2.06433    1.1581657  2.1150565 ]
#  [2.801848   4.128015   4.423535  ]]
# inside
# No change  applied to TS or repr data
# 8
# [[2.3351393  1.7793369  2.5435708 ]
#  [0.9445265  4.9572415  2.0003953 ]
#  [1.796237   0.28190255 1.8548276 ]]
# inside
# No change  applied to TS or repr data
# 9
# [[2.7649453 4.9094906 2.0743408]
#  [0.8986351 4.6512923 3.327088 ]
#  [2.7208867 4.254778  4.174309 ]]
# inside
# No change  applied to TS or repr data
# 10
# [[0.11785895 1.5536692  4.29064   ]
#  [2.4955397  3.673825   3.4894094 ]
#  [2.1594453  3.5736444  0.72262317]]
# inside
# No change  applied to TS or repr data
# 11
# [[0.32092184 3.9122062  2.1276574 ]
#  [3.5528612  2.9782627  4.1865535 ]
#  [4.425669   4.1144166  0.10583222]]
# inside
# No change  applied to TS or repr data
# 12
# [[3.2060294 4.14521   1.0576108]
#  [2.6098278 2.988926  3.1748233]
#  [1.5945607 2.679192  3.211675 ]]
# inside
# No change  applied to TS or repr data
# 13
# [[4.044508   2.1127665  2.197307  ]
#  [2.937381   1.6022736  1.7383671 ]
#  [2.8608754  1.9345856  0.88938177]]
# inside
# No change  applied to TS or repr data
# 14
# [[0.24610639 2.9946823  0.8856556 ]
#  [1.3193244  2.3584146  4.1921954 ]
#  [0.8193934  0.94964594 4.985377  ]]
# inside
# No change  applied to TS or repr data
# 15
# [[4.86566    2.5812116  0.19548386]
#  [0.76180696 2.5203576  1.1582396 ]
#  [0.98516226 2.5518694  3.321764  ]]
# inside
# No change  applied to TS or repr data
# 16
# [[2.488104   0.11499286 1.135442  ]
#  [2.8540192  4.237402   3.5698547 ]
#  [4.2593617  3.4929924  3.896071  ]]
# inside
# No change  applied to TS or repr data
# 17
# [[3.689824  1.8227544 4.3364553]
#  [2.7317634 2.942507  4.8922615]
#  [4.4375257 4.951428  1.7973433]]
# inside
# No change  applied to TS or repr data
# 18
# [[1.995487  2.7604632 0.5021402]
#  [1.4217865 4.9988394 3.5382783]
#  [4.0155745 1.0332191 1.7942882]]
# inside
# No change  applied to TS or repr data
# 19
# [[4.19893    4.0207515  0.60667306]
#  [2.6546035  3.3232384  2.038705  ]
#  [0.443846   1.2144616  3.5266943 ]]
# inside
# No change  applied to TS or repr data
# 20
# [[2.1750875  1.7957181  1.7056614 ]
#  [1.3219523  3.328036   0.6704888 ]
#  [3.6178207  3.3338702  0.54568917]]
# inside
# No change  applied to TS or repr data
# 21
# [[2.5363479 1.6735592 4.8471103]
#  [3.8833783 4.82713   2.534573 ]
#  [4.3327384 1.9968317 3.1941893]]
# inside
# No change  applied to TS or repr data
# 22
# [[1.6248965  1.8157253  0.95857084]
#  [2.6193457  4.752151   1.0912222 ]
#  [2.5594535  4.877686   3.1467514 ]]
# inside
# No change  applied to TS or repr data
# 23
# [[2.643096   0.808149   4.43479   ]
#  [3.1080275  0.22942066 1.9279122 ]
#  [1.1292467  3.9185526  1.0258979 ]]
# inside
# No change  applied to TS or repr data
# 24
# [[3.8189406 3.3632932 4.2209272]
#  [2.4005725 1.4876741 0.5270779]
#  [3.6690547 1.0138404 3.5414057]]
# inside
# No change  applied to TS or repr data
# 25
# [[3.243482   1.6480589  4.43421   ]
#  [3.1022503  1.7816567  3.0102348 ]
#  [4.962471   1.8639964  0.00580847]]
# inside
# No change  applied to TS or repr data
# 26
# [[2.862139  3.0310032 3.3036444]
#  [3.1757736 3.4833603 1.3946658]
#  [2.9533007 4.8380513 1.2010485]]
# inside
# No change  applied to TS or repr data
# 27
# [[1.4595673 1.4284036 2.0103705]
#  [2.3223746 4.751657  1.2821307]
#  [3.3226466 4.3044753 1.7690182]]
# inside
# No change  applied to TS or repr data
# 28
# [[1.6719642 0.7862729 1.6326592]
#  [3.897717  2.3309639 3.6249704]
#  [4.1390014 1.76896   0.5804789]]
# inside
# No change  applied to TS or repr data
# 29
# [[0.85520476 1.2613478  4.1263037 ]
#  [0.8022508  1.001631   1.6667819 ]
#  [0.948053   0.7632756  4.95575   ]]
# inside
# No change  applied to TS or repr data
# 30
# [[3.0521152  0.48009753 0.24014652]
#  [2.6862202  0.43228447 3.5396724 ]
#  [3.336793   1.3596982  2.3322651 ]]
# inside
# No change  applied to TS or repr data
# 31
# [[4.936467   3.866482   1.2865615 ]
#  [0.35550535 4.376243   1.4501796 ]
#  [4.68855    2.1096756  1.9548562 ]]
# inside
# No change  applied to TS or repr data
# 32
# [[2.2888575 2.6576047 3.2153711]
#  [0.8491215 3.5909882 4.2246523]
#  [0.8941525 2.963724  1.9853121]]
# inside
# No change  applied to TS or repr data
# 33
# [[4.0143065  4.041602   0.24810076]
#  [3.0455897  4.461441   0.7724762 ]
#  [4.726956   0.37834257 4.029292  ]]
# inside
# No change  applied to TS or repr data
# 34
# [[3.9324694  1.9029953  3.9101675 ]
#  [2.4717116  0.16738564 3.9585483 ]
#  [4.454407   4.256319   2.34087   ]]
# inside
# No change  applied to TS or repr data
# 35
# [[4.078477   2.0401478  1.4599266 ]
#  [1.234647   1.7534027  2.1773949 ]
#  [1.8623507  0.72435945 0.08835942]]
# inside
# No change  applied to TS or repr data
# 36
# [[4.336897   1.1309338  0.07916808]
#  [1.760186   0.37631124 4.3919873 ]
#  [0.8787945  1.9525228  1.1062553 ]]
# inside
# No change  applied to TS or repr data
# 37
# [[0.01815021 4.465431   2.273768  ]
#  [4.907269   2.7213273  0.74371517]
#  [0.22518337 2.642456   3.1534863 ]]
# inside
# No change  applied to TS or repr data
# 38
# [[3.8653445  3.4687138  4.1515965 ]
#  [2.0710518  1.2769634  0.09487748]
#  [2.2450557  4.446277   0.98872215]]
# inside
# No change  applied to TS or repr data
# 39
# [[4.608732  1.4234251 2.5995266]
#  [3.0233326 0.3688115 1.9156775]
#  [4.0597835 2.5449924 2.1569467]]
# inside
# No change  applied to TS or repr data
# 40
# [[0.90937465 3.6433878  1.83765   ]
#  [3.3418748  1.4286242  1.6096995 ]
#  [2.7570927  4.597948   3.1801715 ]]
# inside
# No change  applied to TS or repr data
# 41
# [[2.2845988 3.2036347 1.1461955]
#  [1.943422  4.5196047 4.8114357]
#  [4.4670954 4.624171  1.3408768]]
# inside
# No change  applied to TS or repr data
# 42
# [[3.9270382  4.9499636  4.384404  ]
#  [1.0174614  3.6520038  0.07101238]
#  [2.9531524  0.22992015 0.45320332]]
# inside
# No change  applied to TS or repr data
# 43
# [[1.1335483 1.507977  1.6148007]
#  [3.2071376 3.2684944 4.8265367]
#  [1.3644662 4.4355917 0.976204 ]]
# inside
# No change  applied to TS or repr data
# 44
# [[8.1380695e-01 1.9317865e-03 2.2430992e+00]
#  [4.4047084e+00 3.0228624e+00 2.6189387e-01]
#  [1.9942158e+00 2.0262423e+00 1.9806268e+00]]
# inside
# No change  applied to TS or repr data
# 45
# [[2.8684683  0.70534974 4.0806637 ]
#  [4.1962023  4.5403857  4.5088973 ]
#  [0.22514403 2.1604645  2.2187302 ]]
# inside
# No change  applied to TS or repr data
# 46
# [[4.799219  3.2900887 4.1630287]
#  [1.8757188 1.0612833 4.8561387]
#  [1.9670012 4.2096143 4.8054667]]
# inside
# No change  applied to TS or repr data
# 47
# [[1.288479  1.8195829 1.9018867]
#  [4.6166    2.3568501 4.2319317]
#  [4.2636957 3.626152  2.1572318]]
# inside
# No change  applied to TS or repr data
# 48
# [[2.302082   0.5055362  1.0019457 ]
#  [0.47956437 0.56658596 1.5447881 ]
#  [4.1461377  4.7041903  2.279074  ]]
# inside
# No change  applied to TS or repr data
# 49
# [[0.51654845 4.8507795  4.7403507 ]
#  [4.8935437  1.6338184  4.6001363 ]
#  [0.25137484 2.2915852  4.3039527 ]]
# inside
# No change  applied to TS or repr data
# 0
# [[0.5583215  4.0792155  1.31281   ]
#  [2.419388   3.382518   3.7695549 ]
#  [1.3134527  0.21419823 1.0401434 ]
#  [0.5901873  0.6084734  3.6779943 ]]
# inside
# No change  applied to TS or repr data
# 1
# [[0.9902474  2.2514377  0.45450717]
#  [4.43598    1.4470098  0.09295195]
#  [4.5477285  1.7029033  2.154536  ]
#  [3.6619213  2.3879852  0.3581357 ]]
# inside
# No change  applied to TS or repr data
# 2
# [[0.03242493 3.873516   0.26323736]
#  [2.1295886  3.0806308  2.064471  ]
#  [0.3475386  1.5832458  0.7864216 ]
#  [0.55265665 0.54261595 1.280005  ]]
# inside
# No change  applied to TS or repr data
# 3
# [[3.1023428  1.6403415  2.995535  ]
#  [1.1204038  3.807924   3.9835186 ]
#  [4.3692737  0.82512736 1.5792146 ]
#  [0.64391494 2.9728005  3.5656295 ]]
# inside
# No change  applied to TS or repr data
# 4
# [[4.3383994  4.1570096  2.221897  ]
#  [1.8155656  3.5915036  4.738209  ]
#  [2.0474622  0.28555632 2.7046227 ]
#  [3.754226   3.3357573  4.1974554 ]]
# inside
# No change  applied to TS or repr data
# 5
# [[2.1870995  0.17963082 1.8880528 ]
#  [3.300803   4.9753485  1.4180851 ]
#  [0.27914047 2.5282395  0.6192541 ]
#  [0.05734563 1.5226498  1.9464114 ]]
# inside
# No change  applied to TS or repr data
# 6
# [[0.96293867 4.045704   1.5125391 ]
#  [4.6246033  0.44324845 4.053503  ]
#  [1.0800326  3.9301138  0.6365642 ]
#  [1.686388   0.67706734 1.0274512 ]]
# inside
# No change  applied to TS or repr data
# 7
# [[3.2623477  3.5544348  1.1195257 ]
#  [1.3490123  1.1543697  2.925819  ]
#  [3.3384423  1.6564109  1.8150824 ]
#  [3.24264    0.18877476 2.118001  ]]
# inside
# No change  applied to TS or repr data
# 8
# [[4.0222464  1.2398598  4.0161567 ]
#  [2.8254542  2.513842   3.1630964 ]
#  [0.2662903  2.254063   3.3890681 ]
#  [2.4505546  0.10392815 1.4936465 ]]
# inside
# No change  applied to TS or repr data
# 9
# [[2.6694508  3.2871213  4.0257993 ]
#  [2.7197685  0.08300304 3.032956  ]
#  [4.048637   4.0831857  1.9406903 ]
#  [3.3741186  1.1036044  1.9795015 ]]
# inside
# No change  applied to TS or repr data
# 10
# [[3.555336   0.45218557 2.822894  ]
#  [3.996968   0.7538977  3.1682851 ]
#  [4.3617005  3.5457993  4.7479105 ]
#  [0.6464243  3.5528011  4.4738297 ]]
# inside
# No change  applied to TS or repr data
# 11
# [[3.5778296 4.5699635 1.4092886]
#  [1.290499  3.1555433 3.0002651]
#  [4.655965  1.076451  3.0163927]
#  [3.6639266 0.9285855 2.550337 ]]
# inside
# No change  applied to TS or repr data
# 12
# [[0.0731194  0.696691   4.589913  ]
#  [1.8186837  1.0212138  3.119198  ]
#  [1.8668189  4.922079   4.4699593 ]
#  [4.470761   0.91457963 3.4306839 ]]
# inside
# No change  applied to TS or repr data
# 13
# [[0.541431  2.6869857 4.596606 ]
#  [3.3683996 0.5126512 2.688828 ]
#  [3.7117453 0.6057045 3.4275045]
#  [3.412547  2.0980814 1.966505 ]]
# inside
# No change  applied to TS or repr data
# 14
# [[4.0889196  1.8160305  1.9939536 ]
#  [3.5310607  0.1312241  2.5877378 ]
#  [0.16887546 2.7981048  4.8309636 ]
#  [2.0476177  3.13271    0.533801  ]]
# inside
# No change  applied to TS or repr data
# 15
# [[0.99815905 3.2056904  4.551234  ]
#  [0.464316   4.5254154  4.867444  ]
#  [3.3049664  3.4255643  1.6757932 ]
#  [3.152838   3.8917253  0.7692078 ]]
# inside
# No change  applied to TS or repr data
# 16
# [[0.21585137 3.4129128  1.3454807 ]
#  [3.504941   3.6636498  3.9288468 ]
#  [2.29641    0.61902344 3.1891344 ]
#  [3.9555361  3.4081223  3.9224086 ]]
# inside
# No change  applied to TS or repr data
# 17
# [[2.8062387  1.5359831  3.1463861 ]
#  [0.18381625 0.63097686 3.8062344 ]
#  [3.1883528  2.1160045  3.6477902 ]
#  [1.8367419  2.4053907  1.7938906 ]]
# inside
# No change  applied to TS or repr data
# 18
# [[1.5940094  1.0437152  1.2965093 ]
#  [1.478261   0.03970474 1.3726833 ]
#  [3.4565358  1.1476686  1.0247169 ]
#  [2.5714898  0.3175056  2.3137903 ]]
# inside
# No change  applied to TS or repr data
# 19
# [[0.24000227 4.88843    2.2239404 ]
#  [4.516609   1.1810845  2.8211477 ]
#  [2.9076502  1.8676865  2.4643075 ]
#  [3.115656   2.8642106  4.4731355 ]]
# inside
# No change  applied to TS or repr data
# 20
# [[2.7831004 2.903366  1.5872663]
#  [1.0060785 3.3433146 3.8720732]
#  [0.7423541 0.6601882 4.1325626]
#  [3.1008675 2.107023  2.9021142]]
# inside
# No change  applied to TS or repr data
# 21
# [[2.5034528 2.7650323 4.7824883]
#  [3.7480447 3.1919825 4.038716 ]
#  [4.4890366 2.800394  2.628021 ]
#  [3.7001324 2.1368546 1.7279154]]
# inside
# No change  applied to TS or repr data
# 22
# [[0.9495494  4.3456726  3.8288527 ]
#  [2.1130152  4.692177   0.60754716]
#  [3.192525   3.6123216  2.3235366 ]
#  [4.3488107  2.7727418  0.53129643]]
# inside
# No change  applied to TS or repr data
# 23
# [[1.4805597  2.5828114  1.2583536 ]
#  [3.4427838  0.36986232 4.3326097 ]
#  [0.68289936 0.5123952  0.9202823 ]
#  [3.6322336  1.5762696  3.4355333 ]]
# inside
# No change  applied to TS or repr data
# 24
# [[0.76307714 3.1557167  4.2034965 ]
#  [2.3706458  2.5613217  0.6154373 ]
#  [1.5487099  2.332493   2.4235594 ]
#  [1.1084831  0.70631444 2.2345796 ]]
# inside
# No change  applied to TS or repr data
# 25
# [[3.609294  1.9269266 3.6392884]
#  [0.5236313 3.3023832 3.8726244]
#  [4.6672387 3.0734863 2.788989 ]
#  [4.94934   4.336332  4.6441064]]
# inside
# No change  applied to TS or repr data
# 26
# [[4.6203156 4.0266747 4.024413 ]
#  [2.4919894 1.8800745 1.9092798]
#  [2.8125584 2.4484482 2.0913532]
#  [0.8684701 0.2985242 3.356359 ]]
# inside
# No change  applied to TS or repr data
# 27
# [[0.5066517  0.41749835 1.1526018 ]
#  [1.0013092  3.0355942  3.652135  ]
#  [4.1720285  4.495667   1.7505672 ]
#  [2.7878106  0.43443412 4.396598  ]]
# inside
# No change  applied to TS or repr data
# 28
# [[4.2954116  1.7843876  1.8254008 ]
#  [0.26926577 3.2028553  1.8902618 ]
#  [3.2396035  4.973322   0.82315236]
#  [3.5727372  1.2074885  1.080661  ]]
# inside
# No change  applied to TS or repr data
# 29
# [[0.28048486 3.330147   3.3725095 ]
#  [3.1198688  4.777906   1.0475892 ]
#  [3.616168   3.100071   1.2775638 ]
#  [1.508978   0.91424644 4.8607235 ]]
# inside
# No change  applied to TS or repr data
# 30
# [[1.2867429  2.3312726  3.7767878 ]
#  [1.8485222  0.13412774 3.6685352 ]
#  [1.0386136  0.794034   2.1696987 ]
#  [0.6095728  4.0436344  0.44317126]]
# inside
# No change  applied to TS or repr data
# 31
# [[2.1966133  0.10596216 3.5797346 ]
#  [2.8719876  1.6769722  0.6237486 ]
#  [0.85908234 1.4912353  3.8554301 ]
#  [1.7791452  2.059908   0.41909188]]
# inside
# No change  applied to TS or repr data
# 32
# [[4.55699    0.30145466 2.8650143 ]
#  [1.5190655  0.6561786  4.7009583 ]
#  [0.5539766  4.1468587  1.0443109 ]
#  [1.3806063  1.8342692  1.1927301 ]]
# inside
# No change  applied to TS or repr data
# 33
# [[1.9710257  4.3160653  0.96589804]
#  [2.9739382  0.23183525 4.028887  ]
#  [2.0717013  3.7284079  2.2632089 ]
#  [2.4589639  4.5156307  4.170818  ]]
# inside
# No change  applied to TS or repr data
# 34
# [[3.5966406 4.0471    3.1382346]
#  [2.4650166 3.5144382 4.433952 ]
#  [3.830477  4.8712025 1.2956784]
#  [1.8621721 0.709233  1.1052388]]
# inside
# No change  applied to TS or repr data
# 35
# [[1.5010545  3.8345895  4.449223  ]
#  [4.5533595  0.10967135 3.163816  ]
#  [4.6173644  1.2701482  1.1293027 ]
#  [4.344323   1.653766   3.9012182 ]]
# inside
# No change  applied to TS or repr data
# 36
# [[1.1163995  3.4250572  4.6548266 ]
#  [2.916452   3.2312174  3.353751  ]
#  [0.09631842 3.3482866  4.8512993 ]
#  [1.5860174  4.003801   1.3650542 ]]
# inside
# No change  applied to TS or repr data
# 37
# [[3.1282706  2.866909   3.336357  ]
#  [3.7308178  0.07483959 0.73099464]
#  [0.98764837 1.0876849  4.4884424 ]
#  [3.3259268  3.4598703  0.70629805]]
# inside
# No change  applied to TS or repr data
# 38
# [[4.1580944  4.9781733  2.694545  ]
#  [4.267842   4.7552314  1.5472513 ]
#  [3.8652017  3.463093   0.32906353]
#  [2.9249787  4.308176   4.4246097 ]]
# inside
# No change  applied to TS or repr data
# 39
# [[3.4318554  4.226022   4.1534004 ]
#  [4.8475685  0.80587417 4.781896  ]
#  [2.4703834  1.4269993  2.4613955 ]
#  [0.7000348  2.4568617  0.25574625]]
# inside
# No change  applied to TS or repr data
# 40
# [[2.3190618 3.993122  4.177367 ]
#  [4.703414  1.2605133 4.629388 ]
#  [4.6010303 1.0880837 2.51968  ]
#  [1.8456438 0.4161939 4.48497  ]]
# inside
# No change  applied to TS or repr data
# 41
# [[4.2534227  0.8986047  3.6654737 ]
#  [2.6900027  0.08234113 3.6733441 ]
#  [4.374317   4.9052215  4.185242  ]
#  [3.5291102  2.6779318  1.1245093 ]]
# inside
# No change  applied to TS or repr data
# 42
# [[4.6387544  1.9846168  3.9936528 ]
#  [1.5467832  4.6604195  3.0484085 ]
#  [0.56340605 3.4477472  0.8517602 ]
#  [3.0244865  2.885447   2.2062337 ]]
# inside
# No change  applied to TS or repr data
# 43
# [[4.326348   0.04948407 0.1420644 ]
#  [2.4488928  4.1553216  3.2951145 ]
#  [2.640662   3.5450692  2.4491053 ]
#  [4.519996   3.0394988  1.0151885 ]]
# inside
# No change  applied to TS or repr data
# 44
# [[4.4803925  2.0023906  0.40706456]
#  [4.367435   0.2201575  1.9647139 ]
#  [2.1080408  2.3014169  0.21635354]
#  [3.259263   0.20737797 0.11885196]]
# inside
# No change  applied to TS or repr data
# 45
# [[2.2936978 4.9578967 2.5981455]
#  [3.573874  4.1410704 2.4354432]
#  [2.8621345 2.4830894 4.8896613]
#  [1.5707421 1.54596   3.220301 ]]
# inside
# No change  applied to TS or repr data
# 46
# [[2.5800786 3.3651261 2.2009137]
#  [1.5493006 3.7703788 1.8503857]
#  [3.6996295 3.3051708 2.3339083]
#  [3.1023037 0.0217095 2.241032 ]]
# inside
# No change  applied to TS or repr data
# 47
# [[4.3703337  1.0619283  0.2161476 ]
#  [0.9614447  4.46351    4.6995    ]
#  [4.808091   3.627437   0.39818555]
#  [1.2511148  0.01263171 0.49981654]]
# inside
# No change  applied to TS or repr data
# 48
# [[1.519495  0.4064998 4.594761 ]
#  [0.1476568 2.5890884 3.7028356]
#  [4.929754  4.783006  1.9649988]
#  [1.846075  1.1985648 4.0594597]]
# inside
# No change  applied to TS or repr data
# 49
# [[3.0736687  1.5046775  4.0206113 ]
#  [0.95223755 1.6655734  1.3114998 ]
#  [2.7323956  2.5717835  4.531652  ]
#  [3.227855   2.0569422  0.97619295]]
# inside
# No change  applied to TS or repr data
# 0
# [[2.9874337  2.72291    0.20370334]
#  [2.9052808  3.3985853  1.9538265 ]
#  [0.875808   1.8233478  3.5379453 ]
#  [2.7114406  2.0269463  1.3923919 ]
#  [3.7003307  4.1784368  4.464982  ]]
# inside
# No change  applied to TS or repr data
# 1
# [[0.33673048 2.9473     1.3317766 ]
#  [2.701527   2.709211   3.299887  ]
#  [4.401763   2.777125   0.35297245]
#  [2.3460102  0.562585   1.457606  ]
#  [1.9743571  2.3665385  3.569939  ]]
# inside
# No change  applied to TS or repr data
# 2
# [[4.3715563 1.3104842 1.8641315]
#  [2.7476468 4.0612206 2.9047604]
#  [1.4778316 3.2811356 0.7934937]
#  [1.9592843 4.092422  1.58672  ]
#  [2.8458097 2.594823  2.09378  ]]
# inside
# No change  applied to TS or repr data
# 3
# [[4.0558143  1.6551673  2.3560333 ]
#  [3.8318467  1.8971083  3.8516572 ]
#  [0.95282465 0.654566   0.24160683]
#  [0.9802893  3.6304874  0.22931188]
#  [2.4586697  3.8229933  4.413163  ]]
# inside
# No change  applied to TS or repr data
# 4
# [[4.8864202  1.5706697  2.1047773 ]
#  [0.7586923  2.5239146  0.3233394 ]
#  [1.4314336  1.6241004  4.181511  ]
#  [4.704579   0.31161398 1.0167518 ]
#  [2.3343406  4.473663   4.85148   ]]
# inside
# No change  applied to TS or repr data
# 5
# [[4.9776993  4.7791653  4.037399  ]
#  [2.5244591  1.6267681  4.144918  ]
#  [4.400116   2.342021   1.4821436 ]
#  [3.0004892  2.36059    0.7275647 ]
#  [2.3362482  1.5382602  0.12909204]]
# inside
# No change  applied to TS or repr data
# 6
# [[1.432966  3.4883726 0.5204493]
#  [1.5452495 0.9172246 2.8731666]
#  [4.9594145 2.934213  1.9683373]
#  [3.561878  2.4205785 1.9684002]
#  [2.9052558 2.3871682 4.3003254]]
# inside
# No change  applied to TS or repr data
# 7
# [[0.67464113 3.2393036  4.0823274 ]
#  [0.17266244 2.8384595  4.0107627 ]
#  [1.4770224  3.7377133  2.1606886 ]
#  [3.8131204  4.7875023  2.4898293 ]
#  [3.6867175  3.4463935  0.7900703 ]]
# inside
# No change  applied to TS or repr data
# 8
# [[3.224763   3.920197   3.4086204 ]
#  [1.7861217  1.9780483  3.5894446 ]
#  [0.5574158  1.0752954  2.572348  ]
#  [1.6704907  0.94038665 2.6040256 ]
#  [2.91805    0.07222772 1.5083041 ]]
# inside
# No change  applied to TS or repr data
# 9
# [[4.7233615  4.196119   1.3819072 ]
#  [3.0170367  3.6953413  4.0263786 ]
#  [0.53720564 0.5559388  1.4905787 ]
#  [1.8170851  4.980565   2.0014462 ]
#  [4.1633863  3.302187   3.391621  ]]
# inside
# No change  applied to TS or repr data
# 10
# [[1.7428136 4.6103363 3.9962528]
#  [4.241307  1.1872485 3.2547555]
#  [2.4035156 1.4959931 0.2574131]
#  [4.2347193 4.254415  4.333084 ]
#  [2.127899  4.4257836 1.6168207]]
# inside
# No change  applied to TS or repr data
# 11
# [[4.062218   4.9551044  4.546524  ]
#  [3.5893724  2.0835412  3.048295  ]
#  [1.8375692  0.9540513  0.61073035]
#  [4.9478726  3.7286425  3.2154593 ]
#  [2.5377684  0.68395704 3.484584  ]]
# inside
# No change  applied to TS or repr data
# 12
# [[0.8801064  0.6220469  2.366634  ]
#  [4.1178374  3.8657622  3.289638  ]
#  [2.3529234  4.040293   4.4360867 ]
#  [0.80058426 3.4386685  3.5896869 ]
#  [2.9415057  1.0249135  3.8051116 ]]
# inside
# No change  applied to TS or repr data
# 13
# [[1.8737319  0.10380208 1.8347666 ]
#  [0.5526683  3.7684255  2.8065321 ]
#  [4.636279   2.2208557  2.0577116 ]
#  [4.420578   4.761491   3.448598  ]
#  [4.875137   4.707403   3.2847083 ]]
# inside
# No change  applied to TS or repr data
# 14
# [[1.937902   4.1292577  2.578986  ]
#  [1.9482756  1.1632055  2.5425293 ]
#  [1.4354024  4.792831   2.1628842 ]
#  [4.86836    1.0781024  3.9979017 ]
#  [1.0997725  0.73297113 3.8736634 ]]
# inside
# No change  applied to TS or repr data
# 15
# [[2.5652885  1.7806727  3.352269  ]
#  [0.9918004  4.691727   2.1943834 ]
#  [4.3991556  2.2032812  1.6627786 ]
#  [3.2924461  4.9140887  3.5137954 ]
#  [3.7218344  3.0166295  0.29155225]]
# inside
# No change  applied to TS or repr data
# 16
# [[1.1059585  4.755953   3.91467   ]
#  [2.6156921  4.694391   4.039482  ]
#  [4.081535   3.6630833  0.14231086]
#  [4.4480996  2.8199415  4.280147  ]
#  [2.3387015  2.9454927  3.2209382 ]]
# inside
# No change  applied to TS or repr data
# 17
# [[4.925175   4.4548826  1.3478436 ]
#  [0.8877358  0.26580334 1.7172632 ]
#  [0.11580944 0.12201518 2.032086  ]
#  [4.8194833  3.0720248  1.8275732 ]
#  [1.0231566  4.0985475  0.48900723]]
# inside
# No change  applied to TS or repr data
# 18
# [[0.18240601 3.5123441  1.6831377 ]
#  [4.1755047  0.9458706  0.09428948]
#  [1.9953201  3.9888754  3.4502115 ]
#  [1.1057627  3.831108   2.2832503 ]
#  [3.7549078  3.987715   0.07971644]]
# inside
# No change  applied to TS or repr data
# 19
# [[2.0761976  2.5175622  1.6955533 ]
#  [2.2591698  4.947048   0.83661854]
#  [0.3488931  0.15279889 3.6552968 ]
#  [0.27660847 2.0411432  1.5683081 ]
#  [3.6678286  2.4334552  3.3151271 ]]
# inside
# No change  applied to TS or repr data
# 20
# [[2.386139   4.6722527  0.38308263]
#  [1.551975   1.279043   1.0334045 ]
#  [0.68075955 4.6311274  4.0802836 ]
#  [4.0104904  2.3287117  4.570151  ]
#  [3.9325569  4.357874   1.892708  ]]
# inside
# No change  applied to TS or repr data
# 21
# [[1.9151106  0.34341335 2.1298285 ]
#  [0.29202372 3.80588    3.858325  ]
#  [4.2910414  1.4031031  0.820933  ]
#  [0.8876014  1.9105184  1.779967  ]
#  [2.7651453  4.4660597  0.08081824]]
# inside
# No change  applied to TS or repr data
# 22
# [[1.2343675  1.0399368  4.498387  ]
#  [4.87668    4.2304463  3.9723577 ]
#  [4.6510305  0.02453983 2.0208998 ]
#  [0.6498915  1.0509727  4.914736  ]
#  [0.16701728 2.181543   1.6247871 ]]
# inside
# No change  applied to TS or repr data
# 23
# [[4.369575   1.4250267  2.7952418 ]
#  [2.1419563  3.4779644  1.4916549 ]
#  [0.8976084  2.8682878  1.1968929 ]
#  [0.48640162 0.7234457  0.23127884]
#  [3.3729992  0.52779824 1.2207987 ]]
# inside
# No change  applied to TS or repr data
# 24
# [[3.849577   3.3271518  2.2838032 ]
#  [0.23844421 3.3646154  0.69817424]
#  [3.941958   3.7725573  1.5568819 ]
#  [3.8098214  3.641799   1.7781749 ]
#  [0.65000296 2.4075272  4.6916895 ]]
# inside
# No change  applied to TS or repr data
# 25
# [[1.6724455  4.7490177  0.49884498]
#  [0.5785188  3.8937345  3.555794  ]
#  [4.1748037  0.38925737 2.235602  ]
#  [0.9410301  4.4375544  0.08323193]
#  [0.82733303 4.537556   1.1155784 ]]
# inside
# No change  applied to TS or repr data
# 26
# [[2.5203896  1.3362684  2.1343198 ]
#  [0.07593274 4.0560603  0.77314377]
#  [1.9314182  3.941159   2.6915264 ]
#  [0.47369838 0.54828405 2.9288387 ]
#  [2.2221959  4.936515   4.318088  ]]
# inside
# No change  applied to TS or repr data
# 27
# [[3.6238244  2.4654362  0.82952857]
#  [1.0520858  4.047917   0.96261144]
#  [3.974285   4.473062   0.5074373 ]
#  [4.0347905  2.85891    0.9053117 ]
#  [3.475392   0.4200226  1.0369074 ]]
# inside
# No change  applied to TS or repr data
# 28
# [[1.4832085 1.2489977 4.1008005]
#  [2.3866317 1.9443405 3.7958086]
#  [1.0918453 2.3109112 1.9928783]
#  [1.8025289 1.0122305 4.031293 ]
#  [1.0522735 0.4534486 3.0579038]]
# inside
# No change  applied to TS or repr data
# 29
# [[1.5824583  0.07579416 1.8750069 ]
#  [0.82601845 1.381923   0.13126671]
#  [0.18559515 4.9304695  0.87088555]
#  [1.2249553  0.6063393  2.3617485 ]
#  [0.00545591 4.72958    4.4042783 ]]
# inside
# No change  applied to TS or repr data
# 30
# [[0.28556377 0.72350204 1.9363437 ]
#  [1.743783   2.324182   2.5606039 ]
#  [3.2036517  4.0171547  0.7432702 ]
#  [4.7924724  4.7133646  3.5354111 ]
#  [3.6880865  1.935905   2.6149056 ]]
# inside
# No change  applied to TS or repr data
# 31
# [[0.7495871  4.5149117  1.0346391 ]
#  [2.4897006  0.32603443 2.2632484 ]
#  [4.4694824  1.9135898  3.1316729 ]
#  [1.7701954  0.6224093  2.5797055 ]
#  [3.4731846  4.365359   0.20010173]]
# inside
# No change  applied to TS or repr data
# 32
# [[2.0060148  1.1552995  0.46524018]
#  [4.3459206  3.5120988  2.5395565 ]
#  [3.1007342  0.561648   1.0758215 ]
#  [2.3048701  3.011913   0.24353743]
#  [4.1358066  2.947242   2.2834306 ]]
# inside
# No change  applied to TS or repr data
# 33
# [[3.8922992  1.38008    2.5565722 ]
#  [1.4262023  2.232548   2.2161744 ]
#  [1.6840494  3.7953525  3.8764133 ]
#  [4.0850773  0.343163   4.4319105 ]
#  [2.6937172  2.0571554  0.24565607]]
# inside
# No change  applied to TS or repr data
# 34
# [[2.6237245  1.7921221  1.7607927 ]
#  [2.559869   4.5497236  2.000663  ]
#  [2.1064117  3.7074351  4.625285  ]
#  [0.02482712 0.3793347  4.4317026 ]
#  [1.7613516  4.779899   3.3205428 ]]
# inside
# No change  applied to TS or repr data
# 35
# [[2.1085358  1.3515666  4.26074   ]
#  [0.15567571 4.7087045  3.6045458 ]
#  [2.4736972  2.677475   0.8406797 ]
#  [0.31576335 1.1305461  0.24398327]
#  [0.720928   1.9385201  4.151231  ]]
# inside
# No change  applied to TS or repr data
# 36
# [[4.6542873  0.20305514 4.617265  ]
#  [1.8776276  3.8222594  1.1245346 ]
#  [0.06506741 3.694546   3.5719643 ]
#  [3.9272997  2.4921455  2.685623  ]
#  [1.7221477  3.1883261  0.5062741 ]]
# inside
# No change  applied to TS or repr data
# 37
# [[2.6524673  4.9625487  3.8767867 ]
#  [4.99453    1.523326   4.9435616 ]
#  [1.649538   1.3468581  2.6403704 ]
#  [4.4073534  2.6372983  3.9010797 ]
#  [4.981788   0.52989334 2.5233464 ]]
# inside
# No change  applied to TS or repr data
# 38
# [[0.33134997 3.2348804  0.80316573]
#  [2.4090931  2.6218767  2.8527074 ]
#  [4.885995   2.2954178  0.43583393]
#  [1.8632972  1.59098    4.3159018 ]
#  [4.627168   1.285392   0.0167048 ]]
# inside
# No change  applied to TS or repr data
# 39
# [[1.0678289  0.21188736 3.7100759 ]
#  [1.9932995  4.3746934  3.6521232 ]
#  [2.996895   0.61472386 0.95246404]
#  [1.5643865  0.07168561 3.3794842 ]
#  [1.912902   1.3409688  0.29238313]]
# inside
# No change  applied to TS or repr data
# 40
# [[3.7636037  0.27553916 2.7991614 ]
#  [2.7169147  3.1313586  3.8893456 ]
#  [3.4951792  0.55552214 4.2192388 ]
#  [0.37846208 1.7491362  2.1892185 ]
#  [4.3742666  4.5623293  3.9088085 ]]
# inside
# No change  applied to TS or repr data
# 41
# [[3.2604744  3.3935556  2.0514286 ]
#  [2.3401852  3.186895   2.6936343 ]
#  [3.0427823  0.78378797 1.7635387 ]
#  [1.754112   2.7598345  4.1045833 ]
#  [3.9720306  3.6834657  2.1201782 ]]
# inside
# No change  applied to TS or repr data
# 42
# [[4.343596   3.0456374  3.4054163 ]
#  [0.57870567 1.7492995  3.2035184 ]
#  [2.8942676  0.60872823 4.917891  ]
#  [4.8788424  0.8626917  0.26305795]
#  [0.76580644 3.4465098  0.42041004]]
# inside
# No change  applied to TS or repr data
# 43
# [[4.5455117  4.369926   3.8154526 ]
#  [2.5064797  4.6426086  0.7509601 ]
#  [1.5878129  0.03728151 4.0232534 ]
#  [4.571746   2.0588171  4.5710115 ]
#  [0.7951021  0.49957335 4.176937  ]]
# inside
# No change  applied to TS or repr data
# 44
# [[3.6540892 3.1995826 4.727065 ]
#  [1.7794051 3.0088518 4.7753086]
#  [2.0881567 3.2768128 4.6196666]
#  [3.9745502 2.1147366 2.7129679]
#  [1.1087928 1.4988124 1.2935603]]
# inside
# No change  applied to TS or repr data
# 45
# [[0.77940255 4.7080336  0.65953046]
#  [3.2953324  1.0824583  3.0958357 ]
#  [3.4913096  2.4315696  2.8649964 ]
#  [0.05678087 4.0085745  1.5950856 ]
#  [1.6569386  0.2808717  4.557469  ]]
# inside
# No change  applied to TS or repr data
# 46
# [[2.5718772  1.6578126  4.8084965 ]
#  [0.95005006 3.598797   3.2982187 ]
#  [4.243016   1.7963845  4.196062  ]
#  [0.48086017 3.854213   0.02687514]
#  [1.310997   2.459888   4.730329  ]]
# inside
# No change  applied to TS or repr data
# 47
# [[0.9206441  1.0964382  4.419695  ]
#  [0.07691503 4.6151204  3.1738014 ]
#  [3.9988942  4.791148   1.4676521 ]
#  [4.3722863  4.563554   1.5258515 ]
#  [0.4933834  3.874496   0.01131147]]
# inside
# No change  applied to TS or repr data
# 48
# [[0.5460352  1.8899748  2.4048164 ]
#  [3.7906866  3.8367727  0.09787142]
#  [2.328161   0.14312923 0.57772547]
#  [3.8730788  1.0268956  0.44992745]
#  [3.9202664  3.9302592  1.9514483 ]]
# inside
# No change  applied to TS or repr data
# 49
# [[3.133365   0.84300697 2.0102787 ]
#  [3.8910124  1.8780074  0.46640456]
#  [0.5153313  3.549631   3.718207  ]
#  [1.0472924  2.3991265  3.01024   ]
#  [2.9316363  3.2868094  4.751082  ]]
# inside
# No change  applied to TS or repr data
# 0
# [[2.9692917  2.503846   4.9807024 ]
#  [0.15558362 0.85778534 4.7405024 ]
#  [3.2351148  4.6322865  3.1000783 ]
#  [1.6743511  3.6615644  3.6743715 ]
#  [2.5023153  2.8058276  4.4094486 ]
#  [0.5978519  3.7836623  4.8258977 ]]
# inside
# No change  applied to TS or repr data
# 1
# [[0.7978821  2.808087   2.287445  ]
#  [0.38004905 2.1560204  2.3536649 ]
#  [1.4055154  1.2191651  2.4575832 ]
#  [0.3618917  4.247117   0.6863004 ]
#  [2.4152172  0.998449   3.9337044 ]
#  [2.8226516  1.9269285  3.5516381 ]]
# inside
# No change  applied to TS or repr data
# 2
# [[1.9839153  4.6614523  2.9895198 ]
#  [3.7196195  1.0222745  3.4875228 ]
#  [0.95983297 1.6281912  3.5898895 ]
#  [3.3664198  1.4886858  1.9671462 ]
#  [2.4969625  3.1764877  1.3361019 ]
#  [4.0167675  1.8303707  2.3716826 ]]
# inside
# No change  applied to TS or repr data
# 3
# [[0.31207442 4.051782   1.841191  ]
#  [1.34152    1.7768121  1.161752  ]
#  [0.44445425 4.6323657  1.2769821 ]
#  [4.2266135  0.99254906 1.2053823 ]
#  [0.8941746  4.1203732  1.6648021 ]
#  [4.3966064  4.478266   4.732439  ]]
# inside
# No change  applied to TS or repr data
# 4
# [[1.112385   3.8262165  2.939526  ]
#  [4.517597   1.644279   3.4590225 ]
#  [3.9180267  1.4199827  3.3259587 ]
#  [3.277032   4.4210057  4.134802  ]
#  [3.8785844  1.5797267  4.092295  ]
#  [3.3490584  0.72115123 1.3803504 ]]
# inside
# No change  applied to TS or repr data
# 5
# [[4.133702   2.1480668  3.0059    ]
#  [0.596292   2.6422014  4.797331  ]
#  [0.17101765 3.1021583  4.072008  ]
#  [1.0514746  1.9745061  3.5325108 ]
#  [0.9852773  0.70590407 4.468164  ]
#  [1.777812   0.15116572 2.389355  ]]
# inside
# No change  applied to TS or repr data
# 6
# [[1.9750276  3.755632   0.6606889 ]
#  [1.0300171  3.5296817  0.2949363 ]
#  [4.585958   1.8945882  2.6783724 ]
#  [0.05798697 3.479597   4.341288  ]
#  [0.02706438 1.4793843  0.63334763]
#  [3.0417469  3.2403696  4.969111  ]]
# inside
# No change  applied to TS or repr data
# 7
# [[3.7950153  0.6828457  3.5088887 ]
#  [0.32788277 2.5622792  0.05073577]
#  [3.2150254  0.0609073  3.623311  ]
#  [3.0893183  0.838525   1.816999  ]
#  [1.2295022  0.41740745 0.97114354]
#  [3.1226597  3.1092396  2.23151   ]]
# inside
# No change  applied to TS or repr data
# 8
# [[1.9602674  2.0432467  4.2041607 ]
#  [4.8818536  2.6632893  3.1496754 ]
#  [4.2290783  0.2656731  4.256695  ]
#  [1.4287832  3.027032   0.9428176 ]
#  [0.8103901  0.12728363 4.989941  ]
#  [0.6197855  0.02087742 3.9109364 ]]
# inside
# No change  applied to TS or repr data
# 9
# [[4.403295   2.6147833  2.7894545 ]
#  [2.115679   3.0023406  4.3347864 ]
#  [2.2980247  2.8114846  1.9552022 ]
#  [3.1055567  2.0749757  4.4209614 ]
#  [0.1868105  4.797621   0.67259103]
#  [3.920964   1.9514996  1.2461128 ]]
# inside
# No change  applied to TS or repr data
# 10
# [[2.9029875  3.9020083  2.645563  ]
#  [4.913675   2.316553   0.20716786]
#  [0.607588   3.4527416  4.2439466 ]
#  [4.590618   1.1324608  4.0825386 ]
#  [2.034336   2.9583466  3.4744353 ]
#  [0.7563397  4.9687657  0.01239747]]
# inside
# No change  applied to TS or repr data
# 11
# [[0.1511401  2.8111477  1.820938  ]
#  [0.07380426 1.1634815  0.24040341]
#  [1.4736301  0.22222847 4.479604  ]
#  [2.1945798  2.231111   1.8312004 ]
#  [4.0379376  1.0383198  1.529784  ]
#  [3.1278112  1.7044836  4.7098217 ]]
# inside
# No change  applied to TS or repr data
# 12
# [[3.114097   3.2948484  1.9626528 ]
#  [3.2797158  0.31873643 3.6157317 ]
#  [2.8094318  3.7060494  0.96562415]
#  [4.4159393  2.767967   4.703426  ]
#  [4.4585223  2.542095   2.8346977 ]
#  [0.46425313 3.4022474  4.594359  ]]
# inside
# No change  applied to TS or repr data
# 13
# [[4.5859656  2.1622384  1.3793468 ]
#  [1.6555789  3.8607154  0.22086412]
#  [4.1868453  4.3047924  0.9341344 ]
#  [2.3337862  3.841456   0.6211251 ]
#  [0.23520887 3.6565998  4.602071  ]
#  [1.3447645  4.1325645  3.3986897 ]]
# inside
# No change  applied to TS or repr data
# 14
# [[1.7523541e+00 3.1789809e-01 3.2763511e-01]
#  [3.3716173e+00 4.4682283e+00 3.0009792e+00]
#  [3.5583873e+00 1.0582805e-03 3.7816973e+00]
#  [4.0660024e+00 2.6310790e+00 1.5261549e+00]
#  [1.6104430e-01 2.2490797e+00 2.9081125e+00]
#  [1.5669010e+00 3.9128315e+00 4.7824836e+00]]
# inside
# No change  applied to TS or repr data
# 15
# [[2.0196362  2.3676758  1.6433537 ]
#  [1.9218487  2.9457774  2.12378   ]
#  [2.63442    4.851846   0.65398544]
#  [3.6799698  2.8104687  3.061308  ]
#  [2.402319   2.032592   2.8569736 ]
#  [1.4818797  4.898694   3.412272  ]]
# inside
# No change  applied to TS or repr data
# 16
# [[0.55396557 2.7762465  2.945182  ]
#  [3.9345374  2.6205287  1.6123936 ]
#  [0.31311482 1.8618526  4.3272142 ]
#  [1.5311549  3.9207234  1.0636184 ]
#  [0.9614533  0.9656781  4.03186   ]
#  [4.3534565  1.8310356  0.58436066]]
# inside
# No change  applied to TS or repr data
# 17
# [[2.6869636  0.04411578 0.57567865]
#  [4.2835493  2.7273622  0.58994055]
#  [2.7613988  2.0105057  3.5165157 ]
#  [4.840727   1.8192866  0.04041523]
#  [3.667016   4.769104   3.4719138 ]
#  [2.7086015  0.09317875 0.302234  ]]
# inside
# No change  applied to TS or repr data
# 18
# [[2.844719   3.3820648  0.57049215]
#  [2.9690108  3.072641   3.9205084 ]
#  [1.0146222  2.675077   1.7050469 ]
#  [2.4390247  4.2534437  0.47670454]
#  [4.3623857  0.0563544  2.312634  ]
#  [4.2004914  3.3543525  0.6440449 ]]
# inside
# No change  applied to TS or repr data
# 19
# [[2.271557   2.7852619  3.4941795 ]
#  [4.852508   0.9835911  0.29402643]
#  [2.7211795  3.514987   2.0139904 ]
#  [3.8602674  2.4717484  4.2119665 ]
#  [0.99267334 1.2012627  4.5247526 ]
#  [0.2482     2.2433162  4.7064114 ]]
# inside
# No change  applied to TS or repr data
# 20
# [[0.994831   2.5179183  3.2763717 ]
#  [4.292351   0.49319983 2.5273137 ]
#  [0.3476286  0.17657816 0.5941853 ]
#  [0.80706924 1.0416955  3.7865152 ]
#  [3.4206052  3.0769193  0.53750485]
#  [4.417117   1.6252468  2.6587677 ]]
# inside
# No change  applied to TS or repr data
# 21
# [[4.6105423  3.3043594  4.313408  ]
#  [2.9308658  1.7834117  4.6892896 ]
#  [0.97670645 1.578753   4.071762  ]
#  [3.3981295  4.1541476  3.5118067 ]
#  [2.7468393  2.6024961  4.1139965 ]
#  [2.9608636  2.4820266  1.047046  ]]
# inside
# No change  applied to TS or repr data
# 22
# [[3.3163853  1.9107189  2.2059975 ]
#  [2.8465314  4.662953   2.4703593 ]
#  [1.8195283  3.7817302  2.3881025 ]
#  [4.445833   0.5992505  0.18089205]
#  [3.5288558  2.4485004  2.1099114 ]
#  [3.1538367  0.9728968  1.5595839 ]]
# inside
# No change  applied to TS or repr data
# 23
# [[3.6933799  3.7860157  4.1097064 ]
#  [1.2448452  4.536185   0.8393675 ]
#  [3.2938094  2.344601   3.3655624 ]
#  [4.0595093  1.9157541  4.1797104 ]
#  [3.0232306  1.988646   2.8213544 ]
#  [0.52274376 2.2671797  0.6388134 ]]
# inside
# No change  applied to TS or repr data
# 24
# [[1.2368476  2.5150099  4.4218273 ]
#  [0.09695917 0.8222908  2.3921375 ]
#  [3.390936   3.0651343  2.670807  ]
#  [1.9546268  4.986459   0.85259587]
#  [1.7938397  3.7572467  1.8872648 ]
#  [4.1973586  1.8639112  1.3060367 ]]
# inside
# No change  applied to TS or repr data
# 25
# [[3.972064   1.0041142  4.9989276 ]
#  [0.90733945 4.231643   4.579481  ]
#  [3.3337948  4.181928   3.5749424 ]
#  [2.4612162  1.0406244  1.5263774 ]
#  [4.6052465  0.90958357 2.458344  ]
#  [1.421727   1.3823259  3.3899179 ]]
# inside
# No change  applied to TS or repr data
# 26
# [[0.5452919  1.9229537  1.3783145 ]
#  [2.430564   1.8743005  4.9964876 ]
#  [3.3801877  1.4820709  0.38687348]
#  [0.29543638 3.6902678  1.9459507 ]
#  [1.2305808  2.2072957  2.4320245 ]
#  [1.9441571  4.7895613  0.53647935]]
# inside
# No change  applied to TS or repr data
# 27
# [[3.1634617  3.9117336  3.127091  ]
#  [3.4510427  2.1032522  0.30188054]
#  [3.6423893  1.0320983  4.9856133 ]
#  [1.88779    1.6207087  1.2673736 ]
#  [4.5004683  1.0545216  4.837719  ]
#  [3.168812   3.5995197  3.6296976 ]]
# inside
# No change  applied to TS or repr data
# 28
# [[2.477838  3.1137514 3.4307442]
#  [2.5725534 1.3502634 2.9322124]
#  [2.986277  4.4112844 1.957128 ]
#  [2.2549067 3.982836  1.7930708]
#  [1.6875798 1.0372698 1.1402681]
#  [1.1956606 2.9153948 3.9568148]]
# inside
# No change  applied to TS or repr data
# 29
# [[4.1919975  4.820799   0.35323024]
#  [1.9485006  3.8432813  3.6169767 ]
#  [1.8541958  0.6588644  2.7110257 ]
#  [1.4416653  2.1932092  4.5044584 ]
#  [0.98818153 4.3189316  2.0756578 ]
#  [4.891577   3.3258433  1.0622058 ]]
# inside
# No change  applied to TS or repr data
# 30
# [[2.6799774  2.7333832  4.349532  ]
#  [4.025484   0.9461257  1.0392815 ]
#  [2.0766475  2.3209343  2.9318821 ]
#  [0.93806    3.621287   3.3732028 ]
#  [3.3881233  4.6825857  0.3006655 ]
#  [2.324881   3.7449923  0.59120685]]
# inside
# No change  applied to TS or repr data
# 31
# [[0.31237334 0.146842   2.7876723 ]
#  [4.4990377  1.1888919  3.4462566 ]
#  [3.6412053  0.15242517 3.4170125 ]
#  [1.8296301  1.3897258  0.24909526]
#  [4.84078    2.991877   1.4849269 ]
#  [3.7565713  2.4469092  0.533534  ]]
# inside
# No change  applied to TS or repr data
# 32
# [[3.6832974  4.137117   3.0575652 ]
#  [1.7540445  0.35135895 0.8549911 ]
#  [4.995442   0.28678328 2.5527003 ]
#  [0.43922067 3.643261   4.261714  ]
#  [0.26459545 2.3687606  0.37419677]
#  [3.7689903  1.3414183  2.8554635 ]]
# inside
# No change  applied to TS or repr data
# 33
# [[1.3204882  0.35271853 2.0359674 ]
#  [3.9191773  1.4520252  4.5755396 ]
#  [1.6674294  0.50771207 1.599026  ]
#  [4.919425   4.982427   2.3489869 ]
#  [1.5185282  3.4160569  0.9288129 ]
#  [4.395363   3.8759904  0.5870542 ]]
# inside
# No change  applied to TS or repr data
# 34
# [[4.6381974  2.9082963  0.4810536 ]
#  [0.00692159 2.8725717  3.5635855 ]
#  [1.8229685  0.2653429  0.67331016]
#  [4.5840416  4.4734907  0.95056504]
#  [4.029523   4.752346   3.5879617 ]
#  [1.7595834  4.759867   2.8348427 ]]
# inside
# No change  applied to TS or repr data
# 35
# [[1.1527705  1.6002172  4.065023  ]
#  [0.43766648 4.4385567  0.82188964]
#  [2.4654384  0.33874393 3.8590598 ]
#  [4.9939356  0.48563868 1.729919  ]
#  [2.9739892  0.33929676 2.5431147 ]
#  [3.8596354  1.397023   2.6607094 ]]
# inside
# No change  applied to TS or repr data
# 36
# [[4.6682363  4.6914773  2.7207727 ]
#  [0.05612642 2.6769295  2.4727635 ]
#  [0.8214444  4.142565   4.4435654 ]
#  [0.21305531 1.970185   4.6404705 ]
#  [2.4122546  4.7318716  3.512914  ]
#  [2.2338848  2.5859184  1.4773798 ]]
# inside
# No change  applied to TS or repr data
# 37
# [[4.395084   1.1582887  0.5605513 ]
#  [3.032609   2.865901   4.5357256 ]
#  [3.0439785  3.208506   0.5938083 ]
#  [2.7564394  3.9168584  2.9631028 ]
#  [0.24426669 3.1202092  4.7208385 ]
#  [3.9958715  3.2246156  2.6455638 ]]
# inside
# No change  applied to TS or repr data
# 38
# [[3.6332808  3.3470483  4.54428   ]
#  [0.2285564  0.47533184 1.9638147 ]
#  [2.2381094  3.536452   0.55378765]
#  [0.86024404 4.8762355  2.0485723 ]
#  [0.1940316  4.807086   3.1358979 ]
#  [0.49427062 0.6762126  1.8477538 ]]
# inside
# No change  applied to TS or repr data
# 39
# [[1.5839887 4.5736113 1.1491048]
#  [2.9604745 4.0673556 2.1803381]
#  [1.0185641 4.1148562 3.017514 ]
#  [3.1433496 0.9795958 4.2845235]
#  [1.9877076 2.052526  3.717433 ]
#  [3.5033844 3.2357473 4.4423866]]
# inside
# No change  applied to TS or repr data
# 40
# [[0.6883666  3.262831   0.88238925]
#  [4.133275   3.1780372  0.13628662]
#  [2.2083225  2.1017053  4.9407463 ]
#  [0.42783886 4.7736206  2.420652  ]
#  [0.22191703 1.3022661  2.88832   ]
#  [2.6944156  4.8955865  3.6133301 ]]
# inside
# No change  applied to TS or repr data
# 41
# [[2.1326959e+00 2.8116698e+00 2.3241818e-01]
#  [2.8479741e+00 1.5071807e+00 4.1211367e+00]
#  [1.9361836e+00 3.0201602e+00 2.9474318e+00]
#  [2.0503643e+00 2.9507051e+00 3.3165181e+00]
#  [5.0380111e-01 3.5805494e-01 2.1205232e+00]
#  [4.1676111e+00 1.0070205e-03 4.6472490e-01]]
# inside
# No change  applied to TS or repr data
# 42
# [[1.3986629  3.5623477  0.6612593 ]
#  [3.7221975  3.8947437  3.5429957 ]
#  [2.05332    3.4963264  1.1136997 ]
#  [4.00941    2.5833523  3.128328  ]
#  [0.94130397 4.8563633  4.9979515 ]
#  [0.5770299  0.43694377 2.6511564 ]]
# inside
# No change  applied to TS or repr data
# 43
# [[0.7732746  3.6361005  0.949741  ]
#  [4.080841   1.8305856  0.9270218 ]
#  [2.917137   4.877912   2.4783862 ]
#  [3.2004566  0.70379853 2.1765592 ]
#  [2.8097997  3.0928268  1.5581548 ]
#  [3.2105308  2.0221853  3.5402637 ]]
# inside
# No change  applied to TS or repr data
# 44
# [[2.0674067  0.2928239  2.0746255 ]
#  [1.4120317  3.729479   2.7515783 ]
#  [2.3238306  2.627705   2.6640015 ]
#  [4.822964   3.585246   0.265781  ]
#  [2.8198824  1.5889859  2.728692  ]
#  [0.34373373 3.6132126  2.5678644 ]]
# inside
# No change  applied to TS or repr data
# 45
# [[0.77294976 4.6956763  4.0384045 ]
#  [0.5256435  3.3841639  2.798244  ]
#  [2.5458293  3.5974433  1.4280841 ]
#  [4.444718   2.17114    0.1012823 ]
#  [3.3504672  0.2925837  1.9138175 ]
#  [4.51906    3.6504447  0.38116366]]
# inside
# No change  applied to TS or repr data
# 46
# [[3.9510834 4.9066634 2.95704  ]
#  [1.8252128 3.7348106 3.447895 ]
#  [4.407515  3.8540294 3.9048104]
#  [1.0693059 0.5032706 2.6149294]
#  [1.5638334 4.4272428 3.1011267]
#  [4.675437  2.0359004 1.527586 ]]
# inside
# No change  applied to TS or repr data
# 47
# [[3.7108228  0.7955107  1.6531253 ]
#  [4.076257   3.757447   1.6235449 ]
#  [4.9646177  0.71752936 1.7244315 ]
#  [1.5703514  4.399353   2.057221  ]
#  [0.99162906 0.70281595 1.3429067 ]
#  [1.6285584  1.4717007  2.2189717 ]]
# inside
# No change  applied to TS or repr data
# 48
# [[0.74287355 3.2514844  0.8448121 ]
#  [0.07878006 2.2977333  4.530748  ]
#  [4.5563188  4.3782635  3.2687736 ]
#  [1.7264783  4.9748535  3.4285731 ]
#  [3.841518   0.3926614  1.6976073 ]
#  [0.8179453  3.7598486  2.9044018 ]]
# inside
# No change  applied to TS or repr data
# 49
# [[1.678853   4.9645133  3.2626233 ]
#  [0.50690293 1.4233348  2.4335065 ]
#  [3.5400686  1.089651   4.1905017 ]
#  [0.6106952  3.8447735  2.203155  ]
#  [1.5611627  3.1628346  3.1946385 ]
#  [4.9128     2.8501024  2.7493453 ]]
# inside
# No change  applied to TS or repr data
# 0
# [[4.917559   0.41826636 4.0094643 ]
#  [2.6494503  2.3947117  0.43517023]
#  [1.8392255  0.68101704 0.9164581 ]
#  [3.9049995  3.9426508  0.08066922]
#  [2.7502325  3.148621   2.3903384 ]
# ...
#  [2.7174516  3.6037612  0.5448291 ]]
# inside
# No change  applied to TS or repr data
# 11
# [[2.0626724  2.5990617  2.1461818 ]
#  [3.6109746  3.6974864  4.3512955 ]
#  [1.1328924  3.8711653  2.0449338 ]
#  [0.73428124 0.5665153  2.5037718 ]
#  [1.2271523  2.3435953  1.9761989 ]
#  [4.854108   3.701301   2.6317847 ]
#  [3.9872181  3.5122955  2.756479  ]
#  [4.9916024  2.2029872  0.9847227 ]
#  [3.8550506  4.59038    2.1058578 ]
#  [3.7963276  4.424572   1.824311  ]]
# inside
# No change  applied to TS or repr data
# 12
# [[4.558101   2.5036275  2.9909816 ]
#  [0.07435858 2.1182947  1.8302041 ]
#  [2.6831868  1.618767   4.4433813 ]
#  [2.40922    2.483268   0.13003707]
#  [4.3566055  0.21973282 1.5488956 ]
#  [2.3412294  0.6761801  1.4691794 ]
#  [0.937396   4.842534   3.5140486 ]
#  [3.9077196  0.44445813 2.8237228 ]
#  [1.4450727  1.6266665  2.044952  ]
#  [0.5692893  1.3970485  4.397234  ]]
# inside
# No change  applied to TS or repr data
# 13
# [[0.68422526 3.615038   2.85363   ]
#  [1.8727279  4.7716184  4.799327  ]
#  [4.9514556  2.643465   1.7526215 ]
#  [2.4343739  4.327016   4.6776476 ]
#  [0.04928023 4.596271   2.4890282 ]
#  [1.4706093  3.8514159  2.0482345 ]
#  [4.646097   1.8193775  2.9530306 ]
#  [4.5334597  0.10088593 0.07709295]
#  [1.0681567  3.7749276  4.959878  ]
#  [3.4646096  4.8284273  3.1262372 ]]
# inside
# No change  applied to TS or repr data
# 14
# [[1.778022   2.662492   4.7238975 ]
#  [1.8241566  4.61795    2.1682646 ]
#  [0.30685484 1.9905525  3.9397035 ]
#  [2.9584866  1.6671073  1.828141  ]
#  [4.9697204  2.6078963  0.59955895]
#  [0.50579906 0.03989995 2.0426223 ]
#  [1.5127525  4.3251143  0.8506784 ]
#  [0.6855792  1.6802993  2.8025196 ]
#  [4.987864   2.6315098  0.99735886]
#  [0.5991575  2.0214763  2.8636315 ]]
# inside
# No change  applied to TS or repr data
# 15
# [[0.6196049  0.40903628 3.243895  ]
#  [2.767745   0.85344523 2.5930285 ]
#  [3.9330413  1.0419059  4.4925265 ]
#  [4.8640814  2.6269112  3.7397602 ]
#  [3.553227   1.3402498  1.939291  ]
#  [3.0385985  0.5423638  2.0083058 ]
#  [3.983823   3.131496   1.818642  ]
#  [2.8707159  3.9084787  1.3506474 ]
#  [0.1564464  1.3259742  0.09554088]
#  [4.907859   4.4011345  2.3036835 ]]
# inside
# No change  applied to TS or repr data
# 16
# [[3.3401334  0.7959765  2.4891078 ]
#  [0.17206758 2.6929858  1.7895916 ]
#  [1.2485588  1.092636   4.8825965 ]
#  [3.2324693  3.320068   1.668306  ]
#  [1.5797958  1.6896349  3.4805295 ]
#  [0.9094587  3.8887553  1.5364931 ]
#  [3.2567322  2.1823552  3.6679256 ]
#  [4.1240964  1.8542311  0.4981622 ]
#  [2.9726772  1.0985231  3.374791  ]
#  [3.2399046  1.7617884  3.3266363 ]]
# inside
# No change  applied to TS or repr data
# 17
# [[4.2915688  0.3068003  2.7387867 ]
#  [2.1638658  4.65797    1.8917372 ]
#  [2.8870127  3.9550092  1.6176167 ]
#  [3.2593007  3.9571896  2.749709  ]
#  [1.2566414  4.7210574  4.0954585 ]
#  [4.5820765  3.2790508  4.2233987 ]
#  [1.3460901  0.51820874 4.6597214 ]
#  [3.6965718  0.05205959 2.521342  ]
#  [1.5634966  3.295975   1.1053485 ]
#  [4.2524076  3.1441858  2.6261797 ]]
# inside
# No change  applied to TS or repr data
# 18
# [[0.27189523 2.4757242  1.2323275 ]
#  [0.9632519  2.4621627  3.807757  ]
#  [1.5541285  0.33697426 2.2768693 ]
#  [0.3373471  4.331324   3.3210394 ]
#  [0.824523   2.9585311  4.6535025 ]
#  [4.994725   0.35247803 4.7527404 ]
#  [0.2770698  4.3788824  1.0744343 ]
#  [0.70073813 2.881911   4.6447897 ]
#  [0.33736676 4.433689   3.3514369 ]
#  [4.573764   3.6748216  3.298687  ]]
# inside
# No change  applied to TS or repr data
# 19
# [[1.4163452  4.89763    1.9724423 ]
#  [2.9076216  1.6099465  1.6795844 ]
#  [0.17335325 4.359949   1.7288536 ]
#  [2.1508608  3.8260326  2.9048228 ]
#  [4.939428   4.9831233  2.1652336 ]
#  [0.6093946  2.7258224  0.60536206]
#  [0.37151635 4.185243   4.727741  ]
#  [4.374351   1.6328335  1.9317865 ]
#  [2.0808244  3.6642523  3.7519882 ]
#  [3.697752   4.301582   1.8705227 ]]
# inside
# No change  applied to TS or repr data
# 20
# [[4.026771   0.9951997  4.8792667 ]
#  [0.5140874  1.7372987  0.7771644 ]
#  [4.4280763  3.4378603  1.2530977 ]
#  [0.5664855  1.0524964  2.0177073 ]
#  [1.2239525  4.3217893  1.4481276 ]
#  [0.8644736  1.728755   0.05863905]
#  [1.2858975  1.1361184  3.0380793 ]
#  [4.5332146  2.769989   1.043004  ]
#  [3.5292163  1.4356055  1.316695  ]
#  [2.0208967  1.1953712  2.77482   ]]
# inside
# No change  applied to TS or repr data
# 21
# [[3.9609787  3.5417333  3.2379124 ]
#  [3.271631   2.0321712  0.79679996]
#  [0.25103062 0.48912942 4.2284546 ]
#  [1.3824195  2.1679661  2.151933  ]
#  [1.1808536  3.0954516  0.53982735]
#  [2.1511111  1.4443225  0.5119124 ]
#  [1.2552762  0.69447994 4.354587  ]
#  [0.33312798 4.9570556  3.9251552 ]
#  [0.55612713 4.8984632  3.3933601 ]
#  [3.5136662  4.34611    2.9769442 ]]
# inside
# No change  applied to TS or repr data
# 22
# [[1.4899284  1.8562696  2.765377  ]
#  [1.7282746  0.23293257 0.52417517]
#  [1.964483   3.6579096  4.979448  ]
#  [0.18084735 2.274839   4.5325356 ]
#  [3.244889   4.58407    2.258797  ]
#  [2.769358   3.4277859  0.477269  ]
#  [3.6182566  2.2113717  4.5695057 ]
#  [4.4472604  4.152101   4.9397173 ]
#  [1.8766207  0.61562747 3.7369096 ]
#  [2.3543046  2.1644778  3.8819737 ]]
# inside
# No change  applied to TS or repr data
# 23
# [[1.5378517  4.792497   2.9221425 ]
#  [2.5840454  4.104595   1.036995  ]
#  [3.8875148  3.1009269  3.4138746 ]
#  [3.5068622  0.5134702  1.1181849 ]
#  [1.9669602  1.7483568  3.7338872 ]
#  [4.4002466  3.5289164  1.9907739 ]
#  [0.2224651  4.369979   0.26258022]
#  [3.3719974  3.266506   4.8405066 ]
#  [0.13274878 0.41362882 3.0940228 ]
#  [0.7142192  1.7855501  2.373343  ]]
# inside
# No change  applied to TS or repr data
# 24
# [[4.811084   1.0713243  0.42699933]
#  [4.957182   0.70832074 2.8976912 ]
#  [2.7230005  4.0563006  4.225679  ]
#  [2.412834   3.7595117  0.55250496]
#  [2.244502   2.2768571  2.3569214 ]
#  [4.7032533  4.5465145  3.6845517 ]
#  [2.9062603  0.24432182 2.3342018 ]
#  [3.9533892  3.0140724  0.9627947 ]
#  [4.5875387  4.5410824  2.8027365 ]
#  [4.883358   4.105168   0.9132394 ]]
# inside
# No change  applied to TS or repr data
# 25
# [[0.30971915 3.0179253  4.811731  ]
#  [4.425688   2.0421827  1.2104279 ]
#  [3.9628658  1.7644677  3.5186694 ]
#  [1.4981542  3.9604485  1.1274884 ]
#  [3.4979308  1.5866306  0.07445693]
#  [2.0456707  3.857815   0.44956118]
#  [0.8488533  1.1790607  2.7452114 ]
#  [4.209037   4.4213476  3.3749402 ]
#  [1.0668331  4.93671    2.5905027 ]
#  [3.0610404  4.8547277  2.9305112 ]]
# inside
# No change  applied to TS or repr data
# 26
# [[0.8173114  3.0204911  4.2690096 ]
#  [4.257084   4.8337407  3.650595  ]
#  [3.0110793  2.4123878  1.3470063 ]
#  [0.6361273  4.451276   1.7113769 ]
#  [1.193347   4.220401   0.42616218]
#  [1.8674225  2.843823   0.15629023]
#  [0.24674952 0.11904597 2.3721275 ]
#  [2.4809747  0.20194411 1.6588674 ]
#  [3.270376   0.9606576  0.83729327]
#  [1.7474661  1.8280647  3.958641  ]]
# inside
# No change  applied to TS or repr data
# 27
# [[1.1979014  4.235328   3.1486492 ]
#  [2.4812508  0.16323239 4.101134  ]
#  [1.6065484  2.1094542  3.2257888 ]
#  [3.5642588  0.20108074 4.7477837 ]
#  [2.82915    4.0188146  1.9244826 ]
#  [2.6318743  3.4447255  4.211345  ]
#  [3.9841266  1.918436   0.6540954 ]
#  [2.4685535  4.776054   2.1232338 ]
#  [0.42326957 3.3711517  4.9610996 ]
#  [4.1219273  3.3427734  4.701248  ]]
# inside
# No change  applied to TS or repr data
# 28
# [[2.5828207  4.7678885  4.2502685 ]
#  [1.497069   0.63176185 2.1510398 ]
#  [4.8815036  3.3253229  4.5412807 ]
#  [1.1500865  4.33861    3.9101717 ]
#  [2.0350144  0.88342667 1.5263116 ]
#  [1.3544776  2.1653092  0.93049824]
#  [0.40722698 1.9687071  0.49670458]
#  [4.9328995  0.07257909 0.14653772]
#  [3.9597301  0.4834929  3.1849036 ]
#  [1.9446442  3.1420856  3.3147504 ]]
# inside
# No change  applied to TS or repr data
# 29
# [[4.8011203  3.9571764  3.358881  ]
#  [1.3468919  4.490127   4.885359  ]
#  [2.157303   3.2458787  0.6762633 ]
#  [4.7358246  0.60581595 4.8573604 ]
#  [4.813071   3.8774219  3.7576654 ]
#  [0.815973   0.7789737  3.151741  ]
#  [2.0563734  0.5832115  0.8242294 ]
#  [0.53889364 3.3705626  2.79863   ]
#  [4.2169757  4.7868743  2.781885  ]
#  [1.0390141  4.4776444  2.7572453 ]]
# inside
# No change  applied to TS or repr data
# 30
# [[4.596621   3.925471   3.0207107 ]
#  [4.9479113  0.99196523 1.0354922 ]
#  [2.345587   3.4849014  3.069947  ]
#  [3.187938   2.7061532  0.32216638]
#  [3.8745317  0.88564456 1.6660938 ]
#  [0.8461386  0.64606726 0.16369283]
#  [3.0600545  1.1428645  4.843132  ]
#  [2.059717   0.8499968  4.9187665 ]
#  [1.2119699  2.1623511  4.6024365 ]
#  [4.902858   4.5612245  0.437468  ]]
# inside
# No change  applied to TS or repr data
# 31
# [[3.4491696  1.7564175  4.0013103 ]
#  [2.3203807  1.1030263  2.0013306 ]
#  [3.1854985  4.383592   1.3148775 ]
#  [0.46903044 3.8920424  3.8388371 ]
#  [1.2226727  3.7376575  3.7842379 ]
#  [4.660717   1.9797435  1.9384921 ]
#  [0.10946989 1.0499215  4.537794  ]
#  [0.81686646 0.06430775 2.4821923 ]
#  [0.9890947  1.5781587  1.740042  ]
#  [1.5909193  4.505374   2.4651048 ]]
# inside
# No change  applied to TS or repr data
# 32
# [[1.6855258  1.738472   1.8931518 ]
#  [3.470813   0.13614029 0.7319927 ]
#  [3.7099252  4.033958   0.05247265]
#  [3.2254074  2.2851417  4.3501782 ]
#  [1.2772558  1.6083589  1.991224  ]
#  [4.387622   4.834904   2.8856587 ]
#  [0.0602746  3.1737819  3.3757339 ]
#  [3.1181498  0.7339594  1.7166805 ]
#  [0.96625715 0.0845176  4.539954  ]
#  [2.608623   2.531977   4.1850786 ]]
# inside
# No change  applied to TS or repr data
# 33
# [[2.043199   1.993284   0.27127057]
#  [2.6025124  0.1970315  4.3269877 ]
#  [2.2694647  2.1926446  0.7819584 ]
#  [1.2841465  3.3772466  4.0640755 ]
#  [4.376846   4.0463476  1.2590907 ]
#  [2.7391531  0.7490504  1.5455413 ]
#  [2.3911154  3.1470644  1.8923523 ]
#  [2.9164007  2.9681432  0.6972632 ]
#  [4.330011   1.8881649  1.7992872 ]
#  [1.1913385  0.6886935  1.4589813 ]]
# inside
# No change  applied to TS or repr data
# 34
# [[2.4712422  2.8336864  1.2289786 ]
#  [0.11514813 3.583037   3.9665415 ]
#  [4.6649756  4.833744   4.479676  ]
#  [1.023215   2.8130147  4.7131147 ]
#  [1.2246495  1.4776617  2.8217316 ]
#  [1.7163974  0.85974693 3.7955055 ]
#  [0.4072258  1.5146735  4.3896174 ]
#  [4.885419   4.210076   0.28419405]
#  [3.1671646  4.780491   3.5988328 ]
#  [0.6379357  3.3584661  0.8974117 ]]
# inside
# No change  applied to TS or repr data
# 35
# [[4.510937   1.7509284  1.4407995 ]
#  [2.643398   3.3464718  1.7404044 ]
#  [3.8318837  1.0565457  0.39604425]
#  [3.0577855  0.5939579  2.4928036 ]
#  [1.4265869  1.5871599  1.3089821 ]
#  [3.158337   2.9678278  2.8564024 ]
#  [3.3147635  0.8273724  2.060754  ]
#  [3.8149543  2.8767433  4.829796  ]
#  [1.4898381  3.913311   4.249467  ]
#  [2.1581674  4.3975153  3.4639242 ]]
# inside
# No change  applied to TS or repr data
# 36
# [[3.45639    3.1888466  1.8630836 ]
#  [3.4460166  0.6710312  3.3157241 ]
#  [2.0343504  0.25347948 3.9357307 ]
#  [4.736243   3.213422   3.034668  ]
#  [2.2715924  1.284338   3.841176  ]
#  [4.9441795  3.7080517  0.7568732 ]
#  [2.6112838  0.64214885 1.8995581 ]
#  [4.223747   4.306001   3.6428485 ]
#  [3.5664222  1.640994   2.527739  ]
#  [2.1325004  0.83245903 4.718599  ]]
# inside
# No change  applied to TS or repr data
# 37
# [[3.9085422  0.4705426  4.729907  ]
#  [4.5580444  0.44121474 0.42216122]
#  [0.4987818  0.48918635 0.5941987 ]
#  [0.51193416 0.41138202 1.0401473 ]
#  [0.5991721  2.5244691  1.0099846 ]
#  [4.7948437  2.6130161  3.0532994 ]
#  [0.7662481  2.8652053  4.212648  ]
#  [4.2709546  2.9845576  2.901124  ]
#  [3.703016   1.6566255  2.5006196 ]
#  [2.66614    1.2946937  4.56004   ]]
# inside
# No change  applied to TS or repr data
# 38
# [[1.9821846  4.2391624  3.97647   ]
#  [4.2723145  0.29600233 3.7851431 ]
#  [3.8052206  3.3992271  0.3479439 ]
#  [3.4597578  4.566393   0.71225107]
#  [0.7329029  0.27954876 3.5768023 ]
#  [2.4895868  0.41645885 1.7424223 ]
#  [3.611287   0.1433003  4.383319  ]
#  [1.691859   1.0542777  2.2479892 ]
#  [3.493717   0.1697436  3.2278607 ]
#  [2.7550826  2.8255296  2.4725184 ]]
# inside
# No change  applied to TS or repr data
# 39
# [[0.01742005 4.3549213  2.4893239 ]
#  [1.5092299  2.9158223  0.1825124 ]
#  [2.530932   3.3314958  3.0283306 ]
#  [3.5072114  1.1887264  1.04848   ]
#  [2.7297668  2.184743   0.39593995]
#  [2.5511618  3.6463406  0.06153792]
#  [1.4415255  4.2956495  3.7121077 ]
#  [4.7765627  3.8456607  1.7595619 ]
#  [4.853095   0.55122286 1.7747452 ]
#  [0.86934924 3.960031   0.6500873 ]]
# inside
# No change  applied to TS or repr data
# 40
# [[4.9790545  1.7032108  0.38666427]
#  [4.1112094  4.594579   4.483966  ]
#  [4.433703   2.5902035  3.6687992 ]
#  [3.9506893  0.17002314 2.3255782 ]
#  [0.65735906 4.7007136  4.019143  ]
#  [1.811209   3.6599135  1.6101835 ]
#  [1.9743273  2.3857033  2.4045646 ]
#  [4.995832   3.957924   3.2557807 ]
#  [1.2617832  1.582275   1.8976921 ]
#  [1.9429266  3.517349   4.8629756 ]]
# inside
# No change  applied to TS or repr data
# 41
# [[3.0579033  3.8909218  2.2579978 ]
#  [4.278192   1.1046141  2.6162343 ]
#  [0.65339804 1.8403986  0.566667  ]
#  [3.1165612  2.2410963  2.5086644 ]
#  [4.1553874  0.14639556 0.38531303]
#  [1.3594542  4.21567    0.06357431]
#  [4.3025036  3.3553336  4.9538264 ]
#  [1.9938836  1.4211347  1.4823399 ]
#  [2.1252587  2.8850377  2.5679195 ]
#  [0.18384814 4.3460345  2.693075  ]]
# inside
# No change  applied to TS or repr data
# 42
# [[0.18549979 3.1928957  3.704504  ]
#  [1.3692296  1.1837604  0.9264222 ]
#  [4.9380474  4.067844   3.8994164 ]
#  [0.30420363 3.5514445  4.312567  ]
#  [3.360849   3.6621192  0.71249247]
#  [2.495234   1.5834653  1.2945232 ]
#  [2.7445135  2.9330637  2.233199  ]
#  [4.066086   1.756284   1.224618  ]
#  [4.1642437  3.1461349  3.6805568 ]
#  [1.1888021  4.525573   1.1629179 ]]
# inside
# No change  applied to TS or repr data
# 43
# [[2.3630216  4.7691298  1.1725527 ]
#  [4.4802146  0.3808722  2.271261  ]
#  [0.1438269  1.2169313  4.358481  ]
#  [1.8122631  0.35316676 4.4804673 ]
#  [4.435259   3.1413329  2.369823  ]
#  [2.1737435  2.494563   3.1816607 ]
#  [0.5122325  1.0943407  2.135244  ]
#  [4.8596897  1.0635644  4.8540287 ]
#  [0.02988607 1.5913874  1.5156937 ]
#  [2.7476044  4.4142194  0.72010875]]
# inside
# No change  applied to TS or repr data
# 44
# [[4.3821344  1.7135954  1.25756   ]
#  [4.7373223  2.0251665  2.1633685 ]
#  [4.044945   3.5458791  0.09908378]
#  [0.0797984  4.0606523  1.9471481 ]
#  [3.9208162  2.3958235  4.941452  ]
#  [4.9302144  2.7982812  2.7009158 ]
#  [2.2788863  3.6674294  1.9814909 ]
#  [3.4429388  3.2183504  0.02563089]
#  [4.6268535  1.5455246  1.870138  ]
#  [2.6211424  1.5637016  3.7247686 ]]
# inside
# No change  applied to TS or repr data
# 45
# [[3.3746634  1.1012578  4.0267305 ]
#  [1.1071346  4.25067    2.57231   ]
#  [4.940566   0.77703893 3.8606677 ]
#  [0.68902016 2.5841374  4.7851257 ]
#  [4.968013   2.1810374  0.46809822]
#  [1.2836474  3.5547163  2.2819114 ]
#  [1.3070935  2.8827474  3.374599  ]
#  [4.0828176  1.5154192  4.3082247 ]
#  [4.392127   3.5806603  3.6201115 ]
#  [3.0620372  2.8301299  1.0147178 ]]
# inside
# No change  applied to TS or repr data
# 46
# [[1.0048006  2.7092938  0.01213163]
#  [1.6001008  0.8019486  3.1688595 ]
#  [2.5282083  2.9236922  4.282448  ]
#  [0.08797824 2.067329   0.5054754 ]
#  [2.7012181  1.5664536  3.5705972 ]
#  [0.8376214  2.9190705  3.1653259 ]
#  [1.1509678  0.16484171 1.0198605 ]
#  [0.20807117 1.1299918  1.241493  ]
#  [4.5846004  4.1127043  2.1333427 ]
#  [4.209227   2.3810544  3.4731529 ]]
# inside
# No change  applied to TS or repr data
# 47
# [[1.3440993  3.0238378  1.1383748 ]
#  [0.74656725 3.1914666  2.8978703 ]
#  [4.8714643  4.5588574  2.413745  ]
#  [1.1696798  4.1196947  1.7571745 ]
#  [0.4635197  0.17896652 2.790409  ]
#  [2.6796582  2.159889   2.8654673 ]
#  [4.3088436  3.2281013  2.1475766 ]
#  [0.47023892 4.073676   0.27280927]
#  [4.210903   3.4203162  3.5153232 ]
#  [2.0531569  0.7308337  2.1979566 ]]
# inside
# No change  applied to TS or repr data
# 48
# [[2.9919326  0.23750186 1.2189486 ]
#  [2.0529432  3.3667226  1.2517071 ]
#  [1.6728356  2.2736406  0.09695292]
#  [0.01080841 0.91042966 0.94608873]
#  [3.7933066  1.6752388  1.4406443 ]
#  [3.0492947  4.3094873  2.0942    ]
#  [3.2660198  2.985858   2.3662698 ]
#  [4.9106     1.2778809  4.523464  ]
#  [3.5765495  1.7075136  1.7900922 ]
#  [3.2332602  2.7536407  1.5764946 ]]
# inside
# No change  applied to TS or repr data
# 49
# [[0.04751056 4.1861     1.8878951 ]
#  [4.137692   2.8613403  1.6000605 ]
#  [3.285928   4.713455   4.703632  ]
#  [1.5076417  0.42069405 0.87933093]
#  [0.86622536 1.1335049  3.1902823 ]
#  [0.35312772 0.2358824  3.7982285 ]
#  [4.2323685  3.2057598  1.6189244 ]
#  [3.4503915  2.992264   0.37153035]
#  [4.4438953  0.19329041 4.4014373 ]
#  [2.3060403  4.4701476  2.9759052 ]]
# inside
